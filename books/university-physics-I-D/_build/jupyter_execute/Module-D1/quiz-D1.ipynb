# %% [markdown]
# # D1.10 Interactive Self-Assessment Quiz
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
from jupyterquiz import display_quiz

code_cells_quiz = [
    {
        "question": "In this e-book, how do you activate a code cell so that you can edit and run your own Python code?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "By clicking the Live Code button (rocketship) at the top of the page",
                "correct": True,
                "feedback": "Correct! The rocketship activates live code cells so you can edit and run them."
            },
            {
                "answer": "By refreshing the web page",
                "correct": False,
                "feedback": "Not correct. Refreshing does not activate live code."
            },
            {
                "answer": "By downloading the e-book as a PDF",
                "correct": False,
                "feedback": "Not correct. PDFs do not support interactive code cells."
            },
            {
                "answer": "By typing code directly into the text of the page",
                "correct": False,
                "feedback": "Not correct. Code must be entered inside an activated code cell."
            }
        ]
    }
]

display_quiz(code_cells_quiz)
# Out:
# <div id="rSKqCZbnAtYx" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

calculator_quiz = [
    {
        "question": "Which of the following is the best way to use Python as a scientific calculator for a physics problem?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Type the entire calculation into a single print statement without storing values",
                "correct": False,
                "feedback": "Not ideal. This makes calculations hard to read and easy to mistake."
            },
            {
                "answer": "Store physical quantities in variables, perform the calculation, and print the result with units",
                "correct": True,
                "feedback": "Correct! This approach is clear, reusable, and appropriate for physics work."
            },
            {
                "answer": "Only use Python for plotting, not for numerical calculations",
                "correct": False,
                "feedback": "Not correct. Python is well suited for numerical calculations."
            },
            {
                "answer": "Avoid using print statements and rely only on raw output",
                "correct": False,
                "feedback": "Not correct. Properly formatted output is important for clarity and communication."
            }
        ]
    }
]

display_quiz(calculator_quiz)
# Out:
# <div id="IOPxkkTuBGre" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

calculator_quiz_2 = [
    {
        "question": "When using Python as a calculator for physics, why is it important to use parentheses carefully?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Because Python ignores the standard order of operations",
                "correct": False,
                "feedback": "Not correct. Python follows standard mathematical order of operations."
            },
            {
                "answer": "Because Python may evaluate expressions in a different order than intended if parentheses are missing",
                "correct": True,
                "feedback": "Correct! Parentheses make the intended mathematical grouping explicit."
            },
            {
                "answer": "Because Python always evaluates multiplication before exponents",
                "correct": False,
                "feedback": "Not correct. Exponents are evaluated before multiplication."
            },
            {
                "answer": "Because parentheses are required in all Python expressions",
                "correct": False,
                "feedback": "Not correct. Parentheses are only needed when you want to control grouping."
            }
        ]
    }
]

display_quiz(calculator_quiz_2)
# Out:
# <div id="jsVSYaVOvEpo" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

calculator_syntax_quiz = [
    {
        "question": "Which of the following Python expressions correctly computes the value of (1/2)·a·t²?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "1/2 a t^2",
                "correct": False,
                "feedback": "Not correct. Python requires explicit multiplication (*) and does not use ^ for powers."
            },
            {
                "answer": "0.5*a*t**2",
                "correct": True,
                "feedback": "Correct! Python uses * for multiplication and ** for powers."
            },
            {
                "answer": "(1/2)*a*t^2",
                "correct": False,
                "feedback": "Not correct. The ^ symbol is not used for powers in Python."
            },
            {
                "answer": "½*a*t²",
                "correct": False,
                "feedback": "Not correct. Python does not understand mathematical symbols like ½ or superscripts."
            }
        ]
    }
]

display_quiz(calculator_syntax_quiz)
# Out:
# <div id="auXhPSmXONYF" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

formatting_quiz = [
    {
        "question": "You compute a numerical value stored in the variable v. Which Python command correctly prints v with two decimal places and includes units?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "print('v =', v, 'm/s')",
                "correct": False,
                "feedback": "This prints the value, but it does not control the number of decimal places."
            },
            {
                "answer": "print(f\"v = {v} m/s\")",
                "correct": False,
                "feedback": "This uses an f-string, but it does not format the number to two decimal places."
            },
            {
                "answer": "print(f\"v = {v:.2f} m/s\")",
                "correct": True,
                "feedback": "Correct! The format specifier :.2f prints the value with two decimal places."
            },
            {
                "answer": "print(v:.2f, 'm/s')",
                "correct": False,
                "feedback": "This is not valid Python syntax. Formatting must be inside the f-string."
            }
        ]
    }
]

display_quiz(formatting_quiz)
# Out:
# <div id="sgPEVmSqjOwv" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

import_quiz = [
    {
        "question": "Which of the following is the best practice when importing libraries in Python for physics calculations?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Use `from module import *` so all functions are immediately available",
                "correct": False,
                "feedback": "Not correct. This can overwrite functions and make code hard to understand or debug."
            },
            {
                "answer": "Import only the specific functions you need, or use a module alias (e.g., `import numpy as np`)",
                "correct": True,
                "feedback": "Correct! This keeps code clear, avoids name conflicts, and is standard scientific practice."
            },
            {
                "answer": "Avoid importing libraries and write all functions yourself",
                "correct": False,
                "feedback": "Not correct. Libraries exist to provide reliable, tested functionality."
            },
            {
                "answer": "Always import both `math` and `numpy` using `import *` to ensure compatibility",
                "correct": False,
                "feedback": "Not correct. `math` and `numpy` contain overlapping function names, which can cause subtle bugs."
            }
        ]
    }
]

display_quiz(import_quiz)
# Out:
# <div id="QKtfbRWoovQF" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

import_syntax_quiz = [
    {
        "question": "Which of the following is a correct and recommended way to import NumPy for physics calculations?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "import numpy as np",
                "correct": True,
                "feedback": "Correct! This is the standard and recommended way to import NumPy."
            },
            {
                "answer": "import np from numpy",
                "correct": False,
                "feedback": "Not correct. This is not valid Python syntax."
            },
            {
                "answer": "from numpy import",
                "correct": False,
                "feedback": "Not correct. This statement is incomplete."
            },
            {
                "answer": "import numpy()",
                "correct": False,
                "feedback": "Not correct. Libraries are not imported using parentheses."
            }
        ]
    }
]

display_quiz(import_syntax_quiz)
# Out:
# <div id="VhfGpfynQNNO" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

python_quiz = [
    {
        "question": "In Python (using SymPy), what is the main purpose of the `.evalf()` method?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "To substitute numerical values for symbols in an expression",
                "correct": False,
                "feedback": "Not quite. Substitution is handled by `.subs()`."
            },
            {
                "answer": "To convert a symbolic expression into a numerical (decimal) approximation",
                "correct": True,
                "feedback": "Correct! `.evalf()` numerically evaluates a symbolic expression."
            },
            {
                "answer": "To simplify an algebraic expression by expanding it",
                "correct": False,
                "feedback": "That describes `expand()`, not `.evalf()`."
            },
            {
                "answer": "To format numerical output with units",
                "correct": False,
                "feedback": "Formatting output is done with print statements and f-strings."
            }
        ]
    }
]

display_quiz(python_quiz)
# Out:
# <div id="TmeidlHHFZCS" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

equations_quiz = [
    {
        "question": "When solving equations symbolically in Python using SymPy, why do we usually write equations using `sp.Eq(left, right)`?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Because Python automatically treats `=` as an equation",
                "correct": False,
                "feedback": "Not correct. In Python, `=` is used for assignment, not for equations."
            },
            {
                "answer": "Because `sp.Eq` explicitly tells SymPy that two expressions are equal",
                "correct": True,
                "feedback": "Correct! `sp.Eq(left, right)` defines a mathematical equation for SymPy to solve."
            },
            {
                "answer": "Because equations cannot be written without parentheses in Python",
                "correct": False,
                "feedback": "Not correct. Parentheses are not the reason here."
            },
            {
                "answer": "Because `sp.solve` only works when equations contain exactly two variables",
                "correct": False,
                "feedback": "Not correct. `sp.solve` works for many types of equations and systems."
            }
        ]
    }
]

display_quiz(equations_quiz)
# Out:
# <div id="bmdegZhOzAuo" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

equations_quiz_2 = [
    {
        "question": "When you solve a system of two equations with two unknowns using `sp.solve((eq1, eq2), (x, y))`, what type of object does SymPy typically return?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "A single number representing the solution",
                "correct": False,
                "feedback": "Not correct. A system of equations generally has more than one unknown."
            },
            {
                "answer": "A dictionary mapping each variable to its solution value",
                "correct": True,
                "feedback": "Correct! SymPy returns a dictionary like `{x: value, y: value}`."
            },
            {
                "answer": "A string containing the solution in mathematical notation",
                "correct": False,
                "feedback": "Not correct. SymPy returns structured Python objects, not strings."
            },
            {
                "answer": "A plot showing the intersection of the equations",
                "correct": False,
                "feedback": "Not correct. Plotting must be done separately."
            }
        ]
    }
]

display_quiz(equations_quiz_2)
# Out:
# <div id="SPANYnslEZgW" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

equations_quiz_3 = [
    {
        "question": "After solving an equation with SymPy and storing the result in `sol`, how do you correctly use that solution to evaluate another expression?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "By retyping the numerical value of the solution directly into the expression",
                "correct": False,
                "feedback": "Not ideal. This defeats the purpose of symbolic computation and can introduce errors."
            },
            {
                "answer": "By using `.subs(sol)` to substitute the solution into the expression",
                "correct": True,
                "feedback": "Correct! Using `.subs(sol)` safely and automatically inserts the solution values."
            },
            {
                "answer": "By calling `.evalf()` on the expression without substitution",
                "correct": False,
                "feedback": "Not correct. `.evalf()` evaluates numerically but does not insert solution values."
            },
            {
                "answer": "By printing the solution and manually checking the result",
                "correct": False,
                "feedback": "Not correct. SymPy allows direct substitution and further computation."
            }
        ]
    }
]

display_quiz(equations_quiz_3)
# Out:
# <div id="llDOxmAlxakG" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

equations_quiz_4 = [
    {
        "question": "Why is it often useful to solve physics equations symbolically in Python before substituting numerical values?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Because symbolic solutions always run faster than numerical ones",
                "correct": False,
                "feedback": "Not correct. Speed is not the main reason for symbolic solving."
            },
            {
                "answer": "Because symbolic solutions can be reused, analyzed, and evaluated for different numerical values",
                "correct": True,
                "feedback": "Correct! Symbolic solutions provide general results that can be reused and explored."
            },
            {
                "answer": "Because numerical substitution is not allowed in SymPy",
                "correct": False,
                "feedback": "Not correct. Numerical substitution is common and encouraged."
            },
            {
                "answer": "Because symbolic solutions automatically include physical units",
                "correct": False,
                "feedback": "Not correct. Units must be handled separately."
            }
        ]
    }
]

display_quiz(equations_quiz_4)
# Out:
# <div id="psZkWnCiSJEc" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

syntax_quiz = [
    {
        "question": "Which of the following lines correctly defines the equation 2x + 3 = 7 in SymPy?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "2*x + 3 = 7",
                "correct": False,
                "feedback": "Not correct. In Python, '=' is assignment, not an equation."
            },
            {
                "answer": "sp.Eq(2x + 3, 7)",
                "correct": False,
                "feedback": "Not correct. Python requires explicit multiplication using '*'."
            },
            {
                "answer": "sp.Eq(2*x + 3, 7)",
                "correct": True,
                "feedback": "Correct! This uses explicit multiplication and properly defines an equation."
            },
            {
                "answer": "Eq(2*x + 3 == 7)",
                "correct": False,
                "feedback": "Not correct. '==' is a comparison operator, not how equations are defined in SymPy."
            }
        ]
    }
]

display_quiz(syntax_quiz)
# Out:
# <div id="BqPwFBdjubzf" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %%
from jupyterquiz import display_quiz

symbols_quiz = [
    {
        "question": "Which of the following correctly defines the symbols x and y for use in SymPy equations?",
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "x, y = symbols('x y')",
                "correct": False,
                "feedback": "Not correct. The symbols function must be accessed through SymPy (e.g., sp.symbols)."
            },
            {
                "answer": "x = 'x'; y = 'y'",
                "correct": False,
                "feedback": "Not correct. This defines strings, not symbolic variables."
            },
            {
                "answer": "x, y = sp.symbols('x y')",
                "correct": True,
                "feedback": "Correct! This properly defines x and y as SymPy symbols."
            },
            {
                "answer": "sp.symbols(x, y)",
                "correct": False,
                "feedback": "Not correct. Symbol names must be provided as strings."
            }
        ]
    }
]

display_quiz(symbols_quiz)
# Out:
# <div id="EsPWrrDHuSCI" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
