# %% [markdown]
# # D4.10 Interactive Self-Assessment Quiz
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
from jupyterquiz import display_quiz

quiz_D45 = [

    # =========================================================
    # Multiple Choice — Conceptual / Word Problems (15)
    # =========================================================

    {
        "question": (
            "Which statement best describes kinetic energy?\n\n"
            "Choose the most accurate option."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "A scalar quantity associated with the motion of an object.",
                "correct": True,
                "feedback": "Correct. Kinetic energy is a scalar that depends on mass and speed."
            },
            {
                "answer": "A vector quantity that points in the direction of motion.",
                "correct": False,
                "feedback": "Incorrect. Kinetic energy has no direction."
            },
            {
                "answer": "A conserved quantity for any object in motion.",
                "correct": False,
                "feedback": "Incorrect. Kinetic energy is not always conserved."
            },
            {
                "answer": "A measure of how hard an object is to stop.",
                "correct": False,
                "feedback": "This describes momentum more closely than kinetic energy."
            }
        ]
    },

    {
        "question": (
            "Why does kinetic energy depend on speed rather than velocity?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Because kinetic energy does not depend on direction.",
                "correct": True,
                "feedback": "Correct. Only the magnitude of motion matters for kinetic energy."
            },
            {
                "answer": "Because speed is easier to measure than velocity.",
                "correct": False,
                "feedback": "Measurement convenience is not the reason."
            },
            {
                "answer": "Because velocity is only used in two dimensions.",
                "correct": False,
                "feedback": "Incorrect. Velocity exists in any number of dimensions."
            },
            {
                "answer": "Because kinetic energy must always be positive.",
                "correct": False,
                "feedback": "Positivity is true, but not the underlying reason."
            }
        ]
    },

    {
        "question": (
            "Work is best described as..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Energy transferred by a force acting through a displacement.",
                "correct": True,
                "feedback": "Correct. This is the physical definition of work."
            },
            {
                "answer": "The force applied to an object.",
                "correct": False,
                "feedback": "Incorrect. Force alone does not determine work."
            },
            {
                "answer": "Energy stored due to position.",
                "correct": False,
                "feedback": "That describes potential energy."
            },
            {
                "answer": "The rate at which energy is transferred.",
                "correct": False,
                "feedback": "That describes power."
            }
        ]
    },

    {
        "question": (
            "In one dimension, when is the work done by a force negative?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "When the force and displacement are in opposite directions.",
                "correct": True,
                "feedback": "Correct. Opposite directions give negative work."
            },
            {
                "answer": "When the force is small.",
                "correct": False,
                "feedback": "Magnitude alone does not determine the sign of work."
            },
            {
                "answer": "When the object slows down.",
                "correct": False,
                "feedback": "Slowing down may result from negative work, but is not the definition."
            },
            {
                "answer": "When the displacement is zero.",
                "correct": False,
                "feedback": "Zero displacement gives zero work, not negative work."
            }
        ]
    },

    {
        "question": (
            "The work–energy theorem states that..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Net work equals the change in kinetic energy.",
                "correct": True,
                "feedback": "Correct. W_net = Δk."
            },
            {
                "answer": "Work is always conserved.",
                "correct": False,
                "feedback": "Incorrect. Work is a process, not a conserved quantity."
            },
            {
                "answer": "Kinetic energy is always conserved.",
                "correct": False,
                "feedback": "Incorrect. Only under special conditions."
            },
            {
                "answer": "Force equals mass times velocity.",
                "correct": False,
                "feedback": "Incorrect. That is not a correct physical law."
            }
        ]
    },

    {
        "question": (
            "Which force can be associated with a potential energy in this module?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Gravity near Earth’s surface.",
                "correct": True,
                "feedback": "Correct. Gravitational potential energy is introduced in this module."
            },
            {
                "answer": "Air drag.",
                "correct": False,
                "feedback": "Incorrect. Air drag is non-conservative."
            },
            {
                "answer": "Kinetic friction.",
                "correct": False,
                "feedback": "Incorrect. Friction is non-conservative."
            },
            {
                "answer": "Any applied push.",
                "correct": False,
                "feedback": "Not all applied forces are conservative."
            }
        ]
    },

    {
        "question": (
            "Gravitational potential energy near Earth depends on..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Vertical position relative to a chosen reference.",
                "correct": True,
                "feedback": "Correct. U_g = mgy depends on height."
            },
            {
                "answer": "Horizontal position only.",
                "correct": False,
                "feedback": "Incorrect. Height matters, not horizontal location."
            },
            {
                "answer": "Speed of the object.",
                "correct": False,
                "feedback": "Incorrect. Speed affects kinetic energy."
            },
            {
                "answer": "The path taken.",
                "correct": False,
                "feedback": "Incorrect. Potential energy depends only on position."
            }
        ]
    },

    {
        "question": (
            "Mechanical energy of a particle is defined as..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "The sum of kinetic and potential energy.",
                "correct": True,
                "feedback": "Correct. e_mech = k + u."
            },
            {
                "answer": "Only kinetic energy.",
                "correct": False,
                "feedback": "Incorrect. Potential energy also contributes."
            },
            {
                "answer": "Only potential energy.",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "Work divided by time.",
                "correct": False,
                "feedback": "That describes power."
            }
        ]
    },

    {
        "question": (
            "Which forces can change the mechanical energy of a system?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Non-conservative forces only.",
                "correct": True,
                "feedback": "Correct. Only non-conservative forces change mechanical energy."
            },
            {
                "answer": "Conservative forces only.",
                "correct": False,
                "feedback": "Incorrect. Conservative forces exchange k and u."
            },
            {
                "answer": "All forces.",
                "correct": False,
                "feedback": "Incorrect. Conservative forces do not change total mechanical energy."
            },
            {
                "answer": "No forces at all.",
                "correct": False,
                "feedback": "Incorrect."
            }
        ]
    },

    {
        "question": (
            "Power describes..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "How quickly energy is transferred.",
                "correct": True,
                "feedback": "Correct. Power is the rate of energy transfer."
            },
            {
                "answer": "How much energy is transferred.",
                "correct": False,
                "feedback": "Incorrect. That is work or energy."
            },
            {
                "answer": "The direction of energy flow.",
                "correct": False,
                "feedback": "Incorrect. Power is scalar."
            },
            {
                "answer": "The force applied to an object.",
                "correct": False,
                "feedback": "Incorrect."
            }
        ]
    },

    # =========================================================
    # Multiple Choice — Numerical Reasoning (5)
    # =========================================================

    {
        "question": (
            "If the speed of an object doubles, what happens to its kinetic energy?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "It increases by a factor of 4.",
                "correct": True,
                "feedback": "Correct. k ∝ v²."
            },
            {
                "answer": "It doubles.",
                "correct": False,
                "feedback": "Incorrect. Speed is squared."
            },
            {
                "answer": "It stays the same.",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "It increases linearly with speed.",
                "correct": False,
                "feedback": "Incorrect."
            }
        ]
    },

    {
        "question": (
            "A force of +10 N acts over a displacement of +5 m. What is the work?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "+50 J",
                "correct": True,
                "feedback": "Correct. w = fΔx = (10)(5)."
            },
            {
                "answer": "-50 J",
                "correct": False,
                "feedback": "Incorrect sign."
            },
            {
                "answer": "2 J",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "0 J",
                "correct": False,
                "feedback": "Incorrect."
            }
        ]
    },

    {
        "question": (
            "Which unit is equivalent to a joule?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "N·m",
                "correct": True,
                "feedback": "Correct. 1 J = 1 N·m."
            },
            {
                "answer": "kg·m/s",
                "correct": False,
                "feedback": "That is momentum."
            },
            {
                "answer": "W·s²",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "N/s",
                "correct": False,
                "feedback": "Incorrect."
            }
        ]
    },

    {
        "question": (
            "If 200 J of work is done in 4.0 s, what is the average power?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "50 W",
                "correct": True,
                "feedback": "Correct. P = W/Δt."
            },
            {
                "answer": "800 W",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "0.02 W",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "200 W",
                "correct": False,
                "feedback": "Incorrect."
            }
        ]
    },

    {
        "question": (
            "A cart’s mechanical energy decreases. What must be true?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "A non-conservative force did negative work.",
                "correct": True,
                "feedback": "Correct. Mechanical energy changes only due to non-conservative forces."
            },
            {
                "answer": "Gravity stopped acting.",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "Momentum was not conserved.",
                "correct": False,
                "feedback": "Incorrect."
            },
            {
                "answer": "Kinetic energy became negative.",
                "correct": False,
                "feedback": "Impossible."
            }
        ]
    },

    {
    "question": (
        "A 0.50 kg particle has kinetic energy k = 7.5e2 J.\n\n "
        "How fast is the particle moving?\n\n"
        
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "5E1 m/s",
            "correct": True,
            "feedback": "Correct. v = sqrt(2k/m) = sqrt(2(7.5e2)/0.50) ≈ 5.48e1 m/s → 5.5e1 m/s."
        },
        {
            "answer": "55 m/s",
            "correct": False,
            "feedback": "Close numerically, but use scientific notation to match the given data and communicate sig figs clearly."
        },
        {
            "answer": "54.8",
            "correct": False,
            "feedback": "That is the unrounded calculator value. Round to match the significant figures in the given data."
        },
        {
            "answer": "3E3",
            "correct": False,
            "feedback": "Too large. Remember you must take the square root when solving for v from k = (1/2)mv^2."
        }
    ]
    },

    {
    "question": (
        "If a particle changes its speed by a factor of 7, what happens to its kinetic energy?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "It increases by a factor of 49.",
            "correct": True,
            "feedback": "Correct. Kinetic energy is proportional to the square of the speed."
        },
        {
            "answer": "It increases by a factor of 7.",
            "correct": False,
            "feedback": "Not quite. Because kinetic energy depends on speed squared, the factor change must be squared as well."
        },
        {
            "answer": "It depends on how fast it is moving.",
            "correct": False,
            "feedback": "The actual value depends on speed, but the factor change does not."
        },
        {
            "answer": "It stays the same.",
            "correct": False,
            "feedback": "No. Changing the speed necessarily changes the kinetic energy."
        }
    ]
    },

    {
    "question": (
        "A box is pushed across the floor with a force of 25 N. The person stops pushing at x = 12 m. "
        "From x = 12 m to x = 15 m, the box slides and comes to a stop due to a constant friction force "
        "of 5.0 N.\n\n"
        "What is the net work done on the box from x = 12 m to x = 15 m?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "-15 J",
            "correct": True,
            "feedback": "Correct. Only friction acts over this interval, and it opposes the motion: W = -(5.0 N)(3.0 m) = -15 J."
        },
        {
            "answer": "60 J",
            "correct": False,
            "feedback": "Incorrect. The pushing force is no longer acting from x = 12 m to x = 15 m."
        },
        {
            "answer": "+15 J",
            "correct": False,
            "feedback": "Check the sign. Friction removes energy from the box, so the work must be negative."
        },
        {
            "answer": "75 J",
            "correct": False,
            "feedback": "Incorrect. Only one force (friction) acts over the 3 m interval."
        }
    ]
    },

    {
    "question": (
        "A net force of +45 N acts on a box over a displacement of +3.5 m.\n\n"
        "What is the net energy transferred into the box?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "1.6e2 J",
            "correct": True,
            "feedback": "Correct. W = F·d = (45)(3.5) = 157.5 J, which rounds to 1.6e2 J."
        },
        {
            "answer": "157.5 J",
            "correct": False,
            "feedback": "Numerically correct, but the answer should be rounded to match the given significant figures."
        },
        {
            "answer": "475 J",
            "correct": False,
            "feedback": "Incorrect. Check the multiplication."
        },
        {
            "answer": "158 J",
            "correct": False,
            "feedback": "Close, but use proper significant figures and scientific notation."
        }
    ]
    },
    {
    "question": (
        "A net force of +55.0 N is applied to a 2.00 kg box over a distance of 6.5 m "
        "in the +x direction. The box starts from rest.\n\n"
        "How fast is the box moving after being pushed this distance?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "19 m/s",
            "correct": True,
            "feedback": "Correct. Use work–energy: W = Fd = Δk → v ≈ 19 m/s."
        },
        {
            "answer": "18.9 m/s",
            "correct": False,
            "feedback": "That is the unrounded calculator value. Round to match significant figures."
        },
        {
            "answer": "358 m/s",
            "correct": False,
            "feedback": "Too large. Remember to take the square root when solving for speed."
        },
        {
            "answer": "3.6e2 m/s",
            "correct": False,
            "feedback": "Incorrect. Recheck the algebra and the square root."
        }
    ]
    },
    {
    "question": (
        "A 2.0 kg box is initially moving at 36 m/s. A constant net force of 10.0 N "
        "acts opposite the motion and brings the box to rest.\n\n"
        "What is the stopping distance?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "130 m",
            "correct": True,
            "feedback": "Correct. Using work–energy gives a stopping distance of about 130 m."
        },
        {
            "answer": "129.6 m",
            "correct": False,
            "feedback": "Very close, but round to match significant figures."
        },
        {
            "answer": "1300 m",
            "correct": False,
            "feedback": "Too large. Check the square on the speed."
        },
        {
            "answer": "75 m",
            "correct": False,
            "feedback": "Too small. Recheck the work–energy calculation."
        }
    ]
    },
    {
    "question": (
        "Consider the previous problem. Everything stays the same, but the initial speed "
        "is doubled.\n\n"
        "What is the stopping distance now?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "520 m",
            "correct": True,
            "feedback": "Correct. Doubling the speed increases the stopping distance by a factor of 4."
        },
        {
            "answer": "520.0 m",
            "correct": False,
            "feedback": "Numerically fine, but be mindful of significant figures."
        },
        {
            "answer": "260 m",
            "correct": False,
            "feedback": "That would be true for a linear relationship, but distance scales with speed squared."
        },
        {
            "answer": "1300 m",
            "correct": False,
            "feedback": "Too large. The increase is by a factor of 4, not 10."
        }
    ]
    },
    {
    "question": (
        "Based on your experience with the previous problems, what happens to the stopping "
        "distance if the speed is increased by a factor of 3?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "It becomes 9 times longer.",
            "correct": True,
            "feedback": "Correct. Stopping distance is proportional to the square of the speed."
        },
        {
            "answer": "It becomes 4 times longer.",
            "correct": False,
            "feedback": "That is the result when the speed is doubled, not tripled."
        },
        {
            "answer": "It becomes 3 times longer.",
            "correct": False,
            "feedback": "Incorrect. The relationship is not linear in speed."
        },
        {
            "answer": "It becomes 6 times longer.",
            "correct": False,
            "feedback": "Incorrect. Remember the speed is squared."
        }
    ]
    },

    {
    "question": (
        "A 0.80 kg cart moving in the +x direction at 5.0 m/s collides with a 1.20 kg cart initially at rest. "
        "After the collision, the two carts move together as one object.\n\n"
        "What is their common final velocity?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "+2.0 m/s",
            "correct": True,
            "feedback": "Correct. Use momentum conservation: v_f = (m1 v1_i + m2 v2_i)/(m1+m2) = (0.80*5.0 + 1.20*0)/(2.00) = 2.0 m/s."
        },
        {
            "answer": "+4.0 m/s",
            "correct": False,
            "feedback": "Too large. If the carts move together, the combined mass is larger, so the speed must be less than 5.0 m/s."
        },
        {
            "answer": "+2.5 m/s",
            "correct": False,
            "feedback": "Check the total mass. The final speed should be (0.80*5.0)/(0.80+1.20) = 2.0 m/s."
        },
        {
            "answer": "+1.0 m/s",
            "correct": False,
            "feedback": "Too small. Recheck momentum: initial momentum is 4.0 kg·m/s."
        }
    ]
    },


    {
    "question": (
        "A 0.80 kg cart moving in the +x direction at 5.0 m/s collides elastically (1D) with a 1.20 kg "
        "cart initially at rest. After the collision, what are the final velocities?\n\n"
        "Choose the best pair (v1_f, v2_f)."
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "(-1.0 m/s, +4.0 m/s)",
            "correct": True,
            "feedback": "Correct. In a 1D elastic collision with the second cart initially at rest, the lighter cart can rebound and the heavier cart moves forward."
        },
        {
            "answer": "(+1.0 m/s, +4.0 m/s)",
            "correct": False,
            "feedback": "Not correct. This pair does not satisfy momentum and kinetic energy conservation simultaneously."
        },
        {
            "answer": "(-4.0 m/s, +1.0 m/s)",
            "correct": False,
            "feedback": "Not correct. Check momentum conservation: the heavier cart should leave with the larger speed in this case."
        },
        {
            "answer": "(0.0 m/s, +5.0 m/s)",
            "correct": False,
            "feedback": "Not correct. That would require equal masses for a perfect speed swap."
        }
    ]
    },



    # =========================================================
    # Numeric Problems (10)
    # =========================================================

    {
        "question": (
            "Compute the kinetic energy.\n\n"
            "A 2.0 kg object moves at 6.0 m/s.\n\n"
            "Enter k in joules. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 36.0, "correct": True, "feedback": "Correct. k = (1/2)(2.0)(6.0)^2 = 36 J."},
            {"type": "range", "range": [35.28, 36.72], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 35.28], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [36.72, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "How much work is done?\n\n"
            "A net force of +15 N acts over +4.0 m.\n\n"
            "Enter work in joules."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 60.0, "correct": True, "feedback": "Correct. w = 15×4.0 = 60 J."},
            {"type": "range", "range": [58.8, 61.2], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 58.8], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [61.2, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "Find the speed.\n\n"
            "A 5.0 kg object starts from rest and gains 125 J of kinetic energy.\n\n"
            "Enter speed in m/s."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 7.07, "correct": True, "feedback": "Correct. v = sqrt(2k/m)."},
            {"type": "range", "range": [6.93, 7.21], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 6.93], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [7.21, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "Compute the change in gravitational potential energy.\n\n"
            "A 3.0 kg object is lifted upward by 2.0 m. Use g = 9.8 m/s^2.\n\n"
            "Enter ΔU in joules."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 58.8, "correct": True, "feedback": "Correct. ΔU = mgy."},
            {"type": "range", "range": [57.6, 60.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 57.6], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [60.0, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "Compute the average power.\n\n"
            "600 J of work is done in 12 s.\n\n"
            "Enter power in watts."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 50.0, "correct": True, "feedback": "Correct. P = 600/12."},
            {"type": "range", "range": [49.0, 51.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 49.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [51.0, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
    "question": (
        "A 1.5 kg cart moving in the +x direction at 6.0 m/s collides with a 2.5 kg cart that is initially "
        "moving in the −x direction at 2.0 m/s. After the collision, the two carts move together.\n\n"
        "What is their common final velocity?\n\n"
        "Enter your answer in m/s. A 2% tolerance is allowed."
    ),
    "type": "numeric",
    "answers": [
        {
            "type": "value",
            "value": 1.25,
            "correct": True,
            "feedback": "Correct. Use momentum conservation: v_f = (m1 v1 + m2 v2)/(m1 + m2)."
        },
        {
            "type": "range",
            "range": [1.225, 1.275],
            "correct": True,
            "feedback": "Correct. Within the allowed tolerance."
        },
        {
            "type": "range",
            "range": [-999, 1.225],
            "correct": False,
            "feedback": "Too small. Check signs and total momentum."
        },
        {
            "type": "range",
            "range": [1.275, 999],
            "correct": False,
            "feedback": "Too large. Recheck the momentum calculation."
        }
    ]
    },

    {
    "question": (
        "A 1.0 kg cart moving in the +x direction at 6.0 m/s collides elastically in one dimension with a "
        "2.0 kg cart that is initially at rest.\n\n"
        "After the collision, what is the final velocity of the 1.0 kg cart?\n\n"
        "Enter your answer in m/s. A 2% tolerance is allowed."
    ),
    "type": "numeric",
    "answers": [
        {
            "type": "value",
            "value": -2.0,
            "correct": True,
            "feedback": "Correct. For a 1D elastic collision with the second cart initially at rest, v1_f = (m1 − m2)/(m1 + m2) · v1_i."
        },
        {
            "type": "range",
            "range": [-2.04, -1.96],
            "correct": True,
            "feedback": "Correct. Within the allowed tolerance."
        },
        {
            "type": "range",
            "range": [-999, -2.04],
            "correct": False,
            "feedback": "Too negative. Recheck the elastic collision formula."
        },
        {
            "type": "range",
            "range": [-1.96, 999],
            "correct": False,
            "feedback": "Not correct. Check both momentum and kinetic energy conservation."
        }
    ]
    },



]

display_quiz(quiz_D45)
# Out:
# <div id="DhNAnjlpBlBS" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...
