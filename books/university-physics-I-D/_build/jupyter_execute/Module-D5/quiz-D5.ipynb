# %% [markdown]
# # D5.5 Interactive Self-Assessment Quiz
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
from jupyterquiz import display_quiz

quiz_D5 = [

    # =========================================================
    # Multiple Choice — Conceptual / Word Problems (15)
    # =========================================================

    {
        "question": (
            "In 1D motion, which statement best describes displacement?\n\n"
            "Choose the most accurate option."
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "A signed change in position that can be positive or negative.", "correct": True,
             "feedback": "Correct. Displacement is change in position with sign (direction) in 1D."},
            {"answer": "Always equal to the total distance traveled.", "correct": False,
             "feedback": "Incorrect. Distance traveled is always nonnegative and depends on the path."},
            {"answer": "Always positive because it measures how far something moved.", "correct": False,
             "feedback": "Incorrect. Displacement can be negative in 1D."},
            {"answer": "A quantity that has no direction because it is measured in meters.", "correct": False,
             "feedback": "Incorrect. In 1D we encode direction using sign."}
        ]
    },

    {
        "question": (
            "A cart moves from x = +2 m to x = -5 m.\n\n"
            "Which statement is true?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The displacement is negative.", "correct": True,
             "feedback": "Correct. Delta x = -5 - (+2) = -7 m (negative)."},
            {"answer": "The displacement is positive.", "correct": False,
             "feedback": "Incorrect. Final position is less than initial position."},
            {"answer": "The distance traveled must be -7 m.", "correct": False,
             "feedback": "Incorrect. Distance traveled cannot be negative."},
            {"answer": "The average velocity must be positive.", "correct": False,
             "feedback": "Incorrect. Average velocity has the same sign as displacement if time is positive."}
        ]
    },

    {
        "question": (
            "Which statement best distinguishes speed from velocity in 1D?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Speed is the magnitude of velocity and is never negative.", "correct": True,
             "feedback": "Correct. Speed is always nonnegative; velocity can be positive or negative."},
            {"answer": "Speed and velocity are always the same in 1D.", "correct": False,
             "feedback": "Incorrect. They differ when velocity is negative."},
            {"answer": "Velocity has units of meters, speed has units of meters per second.", "correct": False,
             "feedback": "Incorrect. Both have units of meters per second."},
            {"answer": "Speed includes direction, velocity does not.", "correct": False,
             "feedback": "Incorrect. Velocity includes direction (sign); speed does not."}
        ]
    },

    {
        "question": (
            "A positive acceleration in 1D means:"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The velocity becomes more positive (or less negative) as time passes.", "correct": True,
             "feedback": "Correct. Positive acceleration increases v_x."},
            {"answer": "The object must be moving in the positive direction.", "correct": False,
             "feedback": "Incorrect. An object can move in -x while having + acceleration (slowing down)."},
            {"answer": "The speed must be increasing.", "correct": False,
             "feedback": "Incorrect. Speed can decrease if velocity is negative and acceleration is positive."},
            {"answer": "The position must always be positive.", "correct": False,
             "feedback": "Incorrect. Position can be negative even with positive acceleration."}
        ]
    },

    {
        "question": (
            "When is it valid to use the standard constant-acceleration kinematics equations?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "When acceleration is approximately constant over the time interval.", "correct": True,
             "feedback": "Correct. The equations assume constant acceleration."},
            {"answer": "Whenever velocity is changing.", "correct": False,
             "feedback": "Incorrect. Changing velocity alone does not guarantee constant acceleration."},
            {"answer": "Only when the object moves in the positive direction.", "correct": False,
             "feedback": "Incorrect. The equations work in either direction if acceleration is constant."},
            {"answer": "Only when the net force is zero.", "correct": False,
             "feedback": "Incorrect. Net force zero means acceleration zero, but the equations are more general."}
        ]
    },

    {
        "question": (
            "Torricelli's equation is most useful when:"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "You want to relate velocity and displacement without using time.", "correct": True,
             "feedback": "Correct. It eliminates time."},
            {"answer": "You want to find time but do not know acceleration.", "correct": False,
             "feedback": "Incorrect. Torricelli’s equation requires acceleration."},
            {"answer": "Acceleration is changing rapidly with time.", "correct": False,
             "feedback": "Incorrect. It assumes constant acceleration."},
            {"answer": "You want to compute force from mass and momentum.", "correct": False,
             "feedback": "Incorrect. That’s impulse–momentum / Newton’s second law territory."}
        ]
    },

    {
        "question": (
            "In this course, why did we delay introducing F = ma?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "To first focus on more general principles like impulse–momentum and work–energy.", "correct": True,
             "feedback": "Correct. Those principles are more general and harder to misuse."},
            {"answer": "Because F = ma is wrong in all situations.", "correct": False,
             "feedback": "Incorrect. It works well for constant-mass systems in many cases."},
            {"answer": "Because acceleration is not a real physical quantity.", "correct": False,
             "feedback": "Incorrect. Acceleration is measurable and useful."},
            {"answer": "Because kinematics never uses acceleration.", "correct": False,
             "feedback": "Incorrect. Kinematics heavily uses acceleration (especially with constant a)."}
        ]
    },

    {
        "question": (
            "Why can F = ma fail for variable-mass systems (like rockets)?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Because momentum changes can come from changes in mass as well as changes in velocity.", "correct": True,
             "feedback": "Correct. Delta(mv) is not the same as m Delta v when m changes."},
            {"answer": "Because Newton's laws only work in 2D and 3D.", "correct": False,
             "feedback": "Incorrect. Newton’s laws apply in 1D too."},
            {"answer": "Because force cannot act on an object with changing mass.", "correct": False,
             "feedback": "Incorrect. Forces still act; the accounting must be done carefully."},
            {"answer": "Because acceleration is always zero when mass changes.", "correct": False,
             "feedback": "Incorrect. Acceleration can be nonzero in variable-mass motion."}
        ]
    },

    {
        "question": (
            "If multiple forces act on a particle at the same time, the net force is:"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The sum of all forces acting along x (with signs).", "correct": True,
             "feedback": "Correct. Net force is the signed sum in 1D."},
            {"answer": "Always the largest force only.", "correct": False,
             "feedback": "Incorrect. Smaller forces still contribute to the sum."},
            {"answer": "Always zero if there are at least two forces.", "correct": False,
             "feedback": "Incorrect. Two forces can add to something nonzero."},
            {"answer": "The average of the forces.", "correct": False,
             "feedback": "Incorrect. Net force is a sum, not an average."}
        ]
    },

    {
        "question": (
            "A particle has negative velocity and positive acceleration. Which is definitely true?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The velocity is becoming less negative as time increases.", "correct": True,
             "feedback": "Correct. Positive acceleration pushes velocity upward."},
            {"answer": "The particle is speeding up.", "correct": False,
             "feedback": "Incorrect. It may be slowing down (speed decreasing) if v is negative."},
            {"answer": "The particle must be moving to the right.", "correct": False,
             "feedback": "Incorrect. Negative velocity means left (in the chosen sign convention)."},
            {"answer": "The displacement must be positive.", "correct": False,
             "feedback": "Incorrect. Displacement depends on position change, not on acceleration alone."}
        ]
    },

    {
        "question": (
            "If the impulse on a particle is positive, what can you conclude about the change in momentum?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The change in momentum is positive.", "correct": True,
             "feedback": "Correct. Impulse equals change in momentum."},
            {"answer": "The final momentum must be positive.", "correct": False,
             "feedback": "Incorrect. Momentum can still be negative if it started negative with larger magnitude."},
            {"answer": "The force must have been negative.", "correct": False,
             "feedback": "Incorrect. Positive impulse corresponds to net force in +x over the interval."},
            {"answer": "The particle must be moving in the +x direction the whole time.", "correct": False,
             "feedback": "Incorrect. Motion direction can change during the interaction."}
        ]
    },

    {
        "question": (
            "Which statement about g's (as used in this course) is correct?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Number of g's is the magnitude of acceleration divided by 9.81 m/s^2.", "correct": True,
             "feedback": "Correct. g-load is |a|/9.81."},
            {"answer": "Number of g's is acceleration times 9.81.", "correct": False,
             "feedback": "Incorrect. It is a ratio, not a product."},
            {"answer": "Number of g's is always 1 for any moving object.", "correct": False,
             "feedback": "Incorrect. It depends on acceleration magnitude."},
            {"answer": "g's can only be used for vertical motion.", "correct": False,
             "feedback": "Incorrect. It’s just a convenient acceleration unit."}
        ]
    },

    {
        "question": (
            "If a particle slows down while moving in the +x direction, the acceleration is:"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Negative.", "correct": True,
             "feedback": "Correct. Acceleration opposite the velocity reduces speed."},
            {"answer": "Positive.", "correct": False,
             "feedback": "Incorrect. Positive acceleration would tend to increase +x velocity."},
            {"answer": "Zero.", "correct": False,
             "feedback": "Incorrect. If speed changes, acceleration is not zero."},
            {"answer": "Impossible to determine without mass.", "correct": False,
             "feedback": "Incorrect. Sign comes from velocity change, not mass."}
        ]
    },

    {
        "question": (
            "Which pair of equations is a correct strategy for solving 'find final velocity and displacement' with constant acceleration?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "v = v0 + a t and x = x0 + v0 t + 0.5 a t^2", "correct": True,
             "feedback": "Correct. These are the standard constant-acceleration equations."},
            {"answer": "p = mv and j = F x", "correct": False,
             "feedback": "Incorrect. Those are momentum and an incorrect work expression."},
            {"answer": "v^2 = v0^2 + 2 a t and x = v t", "correct": False,
             "feedback": "Incorrect. v^2 equation does not use time that way; x = v t requires constant v."},
            {"answer": "F = ma and x = 0.5 m v^2", "correct": False,
             "feedback": "Incorrect. The second equation is not a kinematics relation."}
        ]
    },

    # =========================================================
    # Multiple Choice — Numeric (15)
    # =========================================================

    {
        "question": (
            "A cart starts from rest and accelerates at 2.0 m/s^2 for 6.0 s.\n\n"
            "What is the final velocity?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "12 m/s", "correct": True, "feedback": "Correct. v = 0 + (2.0)(6.0) = 12."},
            {"answer": "6 m/s", "correct": False, "feedback": "Incorrect. You forgot the acceleration factor."},
            {"answer": "24 m/s", "correct": False, "feedback": "Incorrect. That would be (4)(6)."},
            {"answer": "3 m/s", "correct": False, "feedback": "Incorrect. Recheck v = v0 + a t."}
        ]
    },

    {
        "question": (
            "A cart starts from rest and accelerates at 2.0 m/s^2 for 6.0 s.\n\n"
            "How far does it travel?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "36 m", "correct": True, "feedback": "Correct. x = 0.5 a t^2 = 0.5(2.0)(36) = 36."},
            {"answer": "12 m", "correct": False, "feedback": "Incorrect. That is v, not x."},
            {"answer": "72 m", "correct": False, "feedback": "Incorrect. You missed the 0.5."},
            {"answer": "18 m", "correct": False, "feedback": "Incorrect. Recheck the t^2 dependence."}
        ]
    },

    {
        "question": (
            "A runner changes velocity from +8 m/s to +2 m/s in 3.0 s.\n\n"
            "What is the acceleration?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "-2.0 m/s^2", "correct": True, "feedback": "Correct. a = (2 - 8)/3 = -2."},
            {"answer": "+2.0 m/s^2", "correct": False, "feedback": "Incorrect. The velocity decreased, so a is negative."},
            {"answer": "-6.0 m/s^2", "correct": False, "feedback": "Incorrect. You did not divide by time."},
            {"answer": "+6.0 m/s^2", "correct": False, "feedback": "Incorrect. Sign and division are wrong."}
        ]
    },

    {
        "question": (
            "A particle experiences a net force of +15 N. Its mass is 3.0 kg.\n\n"
            "What is the acceleration?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "+5.0 m/s^2", "correct": True, "feedback": "Correct. a = F/m = 15/3 = 5."},
            {"answer": "+45 m/s^2", "correct": False, "feedback": "Incorrect. You multiplied instead of dividing."},
            {"answer": "+0.20 m/s^2", "correct": False, "feedback": "Incorrect. Check the division."},
            {"answer": "-5.0 m/s^2", "correct": False, "feedback": "Incorrect. Force is positive so acceleration is positive."}
        ]
    },

    {
        "question": (
            "A particle of mass 0.50 kg has acceleration -24 m/s^2.\n\n"
            "What is the net force?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "-12 N", "correct": True, "feedback": "Correct. F = m a = 0.50(-24) = -12."},
            {"answer": "+12 N", "correct": False, "feedback": "Incorrect. Sign must match acceleration (mass is positive)."},
            {"answer": "-48 N", "correct": False, "feedback": "Incorrect. You doubled the result."},
            {"answer": "-0.020 N", "correct": False, "feedback": "Incorrect. Units/magnitude are off."}
        ]
    },

    {
        "question": (
            "A car traveling at 20 m/s brakes with acceleration -5.0 m/s^2.\n\n"
            "How long to stop?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "4.0 s", "correct": True, "feedback": "Correct. 0 = 20 + (-5)t -> t = 4."},
            {"answer": "2.5 s", "correct": False, "feedback": "Incorrect. That would be 20/8."},
            {"answer": "5.0 s", "correct": False, "feedback": "Incorrect. Check 20/5 = 4."},
            {"answer": "100 s", "correct": False, "feedback": "Incorrect. That is not reasonable here."}
        ]
    },

    {
        "question": (
            "A car traveling at 20 m/s brakes with acceleration -5.0 m/s^2.\n\n"
            "How far does it travel before stopping? (Use Torricelli)"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "40 m", "correct": True, "feedback": "Correct. 0 = 20^2 + 2(-5)Δx -> Δx = 40."},
            {"answer": "20 m", "correct": False, "feedback": "Incorrect. You likely forgot the 2a factor."},
            {"answer": "80 m", "correct": False, "feedback": "Incorrect. That would come from missing a factor of 2."},
            {"answer": "10 m", "correct": False, "feedback": "Incorrect. Recheck v^2 = v0^2 + 2aΔx."}
        ]
    },

    {
        "question": (
            "A ball is thrown straight up with initial velocity +12 m/s. Use a = -9.81 m/s^2.\n\n"
            "How long until it reaches maximum height?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "1.22 s", "correct": True, "feedback": "Correct. 0 = 12 - 9.81 t -> t = 1.22."},
            {"answer": "0.82 s", "correct": False, "feedback": "Incorrect. That would be 12/14.6."},
            {"answer": "2.44 s", "correct": False, "feedback": "Incorrect. That is twice the correct time."},
            {"answer": "12 s", "correct": False, "feedback": "Incorrect. Check units and equation."}
        ]
    },

    {
        "question": (
            "A particle changes velocity from -35 m/s to -5.0 m/s. Its mass is 5.0 kg.\n\n"
            "What is the change in momentum?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "+150 kg m/s", "correct": True, "feedback": "Correct. Δv = +30, so Δp = 5.0(30) = +150."},
            {"answer": "-150 kg m/s", "correct": False, "feedback": "Incorrect. Δv is positive, so Δp is positive."},
            {"answer": "+30 kg m/s", "correct": False, "feedback": "Incorrect. You forgot the mass factor."},
            {"answer": "-30 kg m/s", "correct": False, "feedback": "Incorrect. Wrong sign and forgot mass."}
        ]
    },

    {
        "question": (
            "A constant net force of -12 N acts for 8.0 s.\n\n"
            "What is the impulse?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "-96 N s", "correct": True, "feedback": "Correct. j = F Δt = (-12)(8.0) = -96."},
            {"answer": "+96 N s", "correct": False, "feedback": "Incorrect. Sign follows force."},
            {"answer": "-1.5 N s", "correct": False, "feedback": "Incorrect. That is far too small."},
            {"answer": "-104 N s", "correct": False, "feedback": "Incorrect. Check multiplication."}
        ]
    },

    {
        "question": (
            "A train has acceleration +0.90 m/s^2 from rest.\n\n"
            "How long to reach 18 m/s?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "20 s", "correct": True, "feedback": "Correct. t = v/a = 18/0.90 = 20."},
            {"answer": "16 s", "correct": False, "feedback": "Incorrect. That would be 18/1.125."},
            {"answer": "10 s", "correct": False, "feedback": "Incorrect. That would require 1.8 m/s^2."},
            {"answer": "2.0 s", "correct": False, "feedback": "Incorrect. Too short for this acceleration."}
        ]
    },

    {
        "question": (
            "A particle experiences acceleration magnitude 98.1 m/s^2.\n\n"
            "How many g's is this?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "10.0 g", "correct": True, "feedback": "Correct. 98.1/9.81 = 10.0."},
            {"answer": "9.81 g", "correct": False, "feedback": "Incorrect. That would correspond to 96.2 m/s^2."},
            {"answer": "1.0 g", "correct": False, "feedback": "Incorrect. 1 g is 9.81 m/s^2."},
            {"answer": "0.10 g", "correct": False, "feedback": "Incorrect. That is 0.981 m/s^2."}
        ]
    },

    {
        "question": (
            "A particle starts with velocity +2.0 m/s and acceleration -3.0 m/s^2 for 4.0 s.\n\n"
            "What is the final velocity?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "-10 m/s", "correct": True, "feedback": "Correct. v = 2.0 + (-3.0)(4.0) = -10."},
            {"answer": "+14 m/s", "correct": False, "feedback": "Incorrect. That would be if acceleration were +3."},
            {"answer": "-4.0 m/s", "correct": False, "feedback": "Incorrect. Recheck 3*4 = 12."},
            {"answer": "+2.0 m/s", "correct": False, "feedback": "Incorrect. Velocity changes because a is nonzero."}
        ]
    },

    {
        "question": (
            "A particle starts with velocity +2.0 m/s and acceleration -3.0 m/s^2 for 4.0 s.\n\n"
            "What is the displacement during this time?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "-16 m", "correct": True, "feedback": "Correct. Δx = v0 t + 0.5 a t^2 = 8 + 0.5(-3)(16) = -16."},
            {"answer": "+16 m", "correct": False, "feedback": "Incorrect. The acceleration dominates and displacement is negative."},
            {"answer": "0 m", "correct": False, "feedback": "Incorrect. It does not return to start in this case."},
            {"answer": "-8 m", "correct": False, "feedback": "Incorrect. You missed the 0.5 a t^2 term."}
        ]
    },

    {
    "question": (
        "A particle is traveling in the positive x-direction. At one instant its speed is 10 m/s, and 7.0 s later its speed is 8.00 m/s.\n\n"
        "What is its average acceleration between the two instants?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "-0.3 m/s^2",
            "correct": True,
            "feedback": (
                "Correct. Because the particle stays in the +x direction, velocity equals +speed. "
                "So Δv = 8.00 − 10 = −2.00 m/s and a = Δv/Δt = (−2.00)/(7.0) = −0.2857... m/s^2. "
                "With 2 significant figures (limited by 7.0 and 10), the result is −0.29 ≈ −0.29 m/s^2, "
                "often reported as −0.29 or −0.29 rounded to −0.29; if forced to one decimal in the choices, −0.3 m/s^2 matches."
            )
        },
        {
            "answer": "-0.29 m/s^2",
            "correct": False,
            "feedback": (
                "Numerically, this is very close, but check the quiz’s rounding rule implied by the answer choices. "
                "Compute a = (8.00 − 10)/7.0 = −0.2857... m/s^2. With 2 significant figures it rounds to −0.29 m/s^2, "
                "but if the quiz expects one decimal place (as in −0.3), choose the option that matches that rounding."
            )
        },
        {
            "answer": "0.3 m/s^2",
            "correct": False,
            "feedback": (
                "Incorrect sign. The particle is moving in +x, but its speed decreases from 10 to 8.00 m/s, "
                "so Δv is negative and the average acceleration must be negative."
            )
        },
        {
            "answer": "0.29 m/s^2",
            "correct": False,
            "feedback": (
                "Incorrect sign. The speed decreases while moving in +x, so Δv = 8.00 − 10 is negative. "
                "That makes the average acceleration negative, not positive. Then apply appropriate rounding."
            )
        }
    ]
    },

    {
    "question": (
        "A particle is at rest at t = 0 s. After an elapsed time of exactly 5 s, the particle has sped up to 50 m/s in the negative x-direction.\n\n"
        "Find its average acceleration during this elapsed time."
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "-1e1 m/s^2",
            "correct": True,
            "feedback": (
                "Correct. Initial velocity is 0 m/s and final velocity is -50 m/s, so Δv = -50 m/s. "
                "Average acceleration is a = Δv/Δt = (-50)/(5) = -10 m/s^2, which is -1e1 m/s^2."
            )
        },
        {
            "answer": "-1.0e1 m/s^2",
            "correct": False,
            "feedback": (
                "The sign is correct, but this choice implies extra precision. "
                "Using a = (-50)/(5) gives -10 m/s^2. If the quiz expects the simplest scientific notation format "
                "matching the given choices, select -1e1 m/s^2."
            )
        },
        {
            "answer": "1e1 m/s^2",
            "correct": False,
            "feedback": (
                "Incorrect sign. The particle ends with a negative velocity, so Δv is negative. "
                "That means the average acceleration must be negative as well."
            )
        },
        {
            "answer": "1.0e1 m/s^2",
            "correct": False,
            "feedback": (
                "Incorrect sign and it also implies extra precision. "
                "Because v changes from 0 to -50 m/s over 5 s, a = -10 m/s^2 (negative), not positive."
            )
        }
    ]
    },

    {
    "question": (
        "A particle travels from x = 3.0 m to x = -4.0 m in 3.00 s.\n\n"
        "What is the particle's displacement?"
    ),
    "type": "multiple_choice",
    "answers": [
        {
            "answer": "-7.0 m",
            "correct": True,
            "feedback": (
                "Correct. Displacement is defined as final position minus initial position. "
                "Here, Δx = (-4.0) − (3.0) = −7.0 m. "
                "The negative sign indicates motion in the negative x-direction, "
                "and the value is reported with the appropriate significant figures."
            )
        },
        {
            "answer": "-7 m",
            "correct": False,
            "feedback": (
                "The direction is correct, but the number of significant figures is not. "
                "Both positions are given to two significant figures, so the displacement "
                "should be reported as −7.0 m, not −7 m."
            )
        },
        {
            "answer": "7.0 m",
            "correct": False,
            "feedback": (
                "Incorrect sign. The final position is smaller than the initial position, "
                "so the displacement must be negative. "
                "You correctly found the magnitude, but not the direction."
            )
        },
        {
            "answer": "7 m",
            "correct": False,
            "feedback": (
                "This choice is incorrect in both direction and precision. "
                "The displacement should be negative because the particle moves toward "
                "negative x, and it should be reported with two significant figures as −7.0 m."
            )
        }
    ]
    },



    # =========================================================
    # Numeric Entry — Students type a number (15)
    # =========================================================

    {
        "question": (
            "A cart starts from rest and accelerates at 3.0 m/s^2 for 10.0 s.\n\n"
            "Enter the final velocity in m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 30.0, "correct": True, "feedback": "Correct. v = 0 + (3.0)(10.0) = 30."},
            {"type": "range", "range": [29.4, 30.6], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 29.4], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [30.6, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A cart starts from rest and accelerates at 3.0 m/s^2 for 10.0 s.\n\n"
            "Enter the displacement in meters. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 150.0, "correct": True, "feedback": "Correct. Δx = 0.5(3.0)(10.0^2) = 150."},
            {"type": "range", "range": [147.0, 153.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-9999, 147.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [153.0, 9999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A vehicle slows from 28.0 m/s to 10.0 m/s in 6.0 s.\n\n"
            "Enter the acceleration in m/s^2. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": -3.0, "correct": True, "feedback": "Correct. a = (10 - 28)/6 = -3.0."},
            {"type": "range", "range": [-3.06, -2.94], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, -3.06], "correct": False, "feedback": "Too negative."},
            {"type": "range", "range": [-2.94, 999], "correct": False, "feedback": "Not negative enough or wrong sign."}
        ]
    },

    {
        "question": (
            "A particle has mass 2.5 kg and experiences net force +20 N.\n\n"
            "Enter the acceleration in m/s^2. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 8.0, "correct": True, "feedback": "Correct. a = 20/2.5 = 8.0."},
            {"type": "range", "range": [7.84, 8.16], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 7.84], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [8.16, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A particle has mass 0.80 kg and acceleration -6.0 m/s^2.\n\n"
            "Enter the net force in newtons. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": -4.8, "correct": True, "feedback": "Correct. F = (0.80)(-6.0) = -4.8."},
            {"type": "range", "range": [-4.896, -4.704], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, -4.896], "correct": False, "feedback": "Too negative."},
            {"type": "range", "range": [-4.704, 999], "correct": False, "feedback": "Not negative enough or wrong sign."}
        ]
    },

    {
        "question": (
            "A car brakes from 22.0 m/s to rest with acceleration -4.0 m/s^2.\n\n"
            "Enter the stopping time in seconds. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 5.5, "correct": True, "feedback": "Correct. 0 = 22 + (-4)t -> t = 5.5."},
            {"type": "range", "range": [5.39, 5.61], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 5.39], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [5.61, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A car with initial speed 22.0 m/s brakes with acceleration -4.0 m/s^2.\n\n"
            "Enter the stopping distance in meters (Torricelli). A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 60.5, "correct": True, "feedback": "Correct. 0 = 22^2 + 2(-4)Δx -> Δx = 484/8 = 60.5."},
            {"type": "range", "range": [59.29, 61.71], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-9999, 59.29], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [61.71, 9999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A ball is thrown straight up with initial velocity 15.0 m/s. Use a = -9.81 m/s^2.\n\n"
            "Enter the time to reach maximum height in seconds. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 1.529, "correct": True, "feedback": "Correct. t = 15.0/9.81 = 1.53 s."},
            {"type": "range", "range": [1.498, 1.560], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 1.498], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [1.560, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A particle changes velocity from -35 m/s to -5.0 m/s. Mass is 5.0 kg.\n\n"
            "Enter the impulse in kg m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 150.0, "correct": True, "feedback": "Correct. Δp = mΔv = 5.0(30) = +150."},
            {"type": "range", "range": [147.0, 153.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-9999, 147.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [153.0, 9999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A constant net force of +3000 N acts on a 5.0 kg particle.\n\n"
            "Enter the acceleration in m/s^2. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 600.0, "correct": True, "feedback": "Correct. a = 3000/5.0 = 600."},
            {"type": "range", "range": [588.0, 612.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-99999, 588.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [612.0, 99999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A constant net force of +3000 N acts for 0.050 s.\n\n"
            "Enter the impulse in N s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 150.0, "correct": True, "feedback": "Correct. j = FΔt = 3000(0.050) = 150."},
            {"type": "range", "range": [147.0, 153.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-9999, 147.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [153.0, 9999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A particle experiences acceleration magnitude 250 m/s^2.\n\n"
            "Enter the g-load (number of g's). A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 25.48, "correct": True, "feedback": "Correct. g-load = 250/9.81 = 25.5."},
            {"type": "range", "range": [24.97, 25.99], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 24.97], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [25.99, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A train changes speed from 0 to 72.0 km/h with acceleration 1.20 m/s^2.\n\n"
            "Enter the time in seconds. A 2% tolerance is allowed.\n\n"
            "Hint: 72.0 km/h = 20.0 m/s."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 16.67, "correct": True, "feedback": "Correct. t = v/a = 20.0/1.20 = 16.7."},
            {"type": "range", "range": [16.34, 17.00], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 16.34], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [17.00, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A particle starts with velocity -18.0 m/s and ends with velocity +6.0 m/s in 0.400 s.\n\n"
            "Enter the net force in newtons if mass is 1.20 kg. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 72.0, "correct": True, "feedback": "Correct. a = 24/0.4 = 60, F = 1.2(60) = 72."},
            {"type": "range", "range": [70.56, 73.44], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-9999, 70.56], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [73.44, 9999], "correct": False, "feedback": "Too large."}
        ]
    },
]

display_quiz(quiz_D5)
# Out:
# <div id="spFhnSmRieOh" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...
