# %% [markdown]
# # D6.4 Interactive Self-Assessment Quiz
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
from jupyterquiz import display_quiz

quiz_D9 = [

    # =========================================================
    # Multiple Choice — Conceptual / Word Problems (10)
    # =========================================================

    {
        "question": (
            "Which statement best describes the difference between an oscillation and a wave?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "An oscillation is localized in time, while a wave involves oscillations distributed across space.", "correct": True,
             "feedback": "Correct. Waves are organized oscillations spread through space."},
            {"answer": "Oscillations require forces, while waves do not.", "correct": False,
             "feedback": "Incorrect. Both involve interactions, but this is not the defining distinction."},
            {"answer": "Waves move matter from one place to another, oscillations do not.", "correct": False,
             "feedback": "Incorrect. Waves describe pattern motion, not bulk transport of matter."},
            {"answer": "Oscillations occur only in mechanics, waves occur only in electromagnetism.", "correct": False,
             "feedback": "Incorrect. Both appear across many areas of physics."}
        ]
    },

    {
        "question": (
            "In a traveling wave, what does the phase describe?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The state of the oscillation within the repeating pattern.", "correct": True,
             "feedback": "Correct. Phase labels where you are in the cycle."},
            {"answer": "The speed at which the wave travels.", "correct": False,
             "feedback": "Incorrect. That is the phase speed."},
            {"answer": "The position of a particle in the medium.", "correct": False,
             "feedback": "Incorrect. Phase does not specify particle position."},
            {"answer": "The energy carried by the wave.", "correct": False,
             "feedback": "Incorrect. Phase is not an energy measure."}
        ]
    },

    {
        "question": (
            "If two points on a wave are one wavelength apart, how are they related?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "They are in the same phase.", "correct": True,
             "feedback": "Correct. One wavelength corresponds to a full cycle of phase."},
            {"answer": "They always move in opposite directions.", "correct": False,
             "feedback": "Incorrect. Points one wavelength apart behave identically."},
            {"answer": "They oscillate with different frequencies.", "correct": False,
             "feedback": "Incorrect. Frequency is the same everywhere in the wave."},
            {"answer": "They must be at rest at the same time.", "correct": False,
             "feedback": "Incorrect. Phase does not imply zero displacement."}
        ]
    },

    {
        "question": (
            "When position is held fixed in a traveling wave, the motion observed is best described as:"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "An oscillation in time with a position-dependent phase.", "correct": True,
             "feedback": "Correct. Each position behaves like an oscillator."},
            {"answer": "A snapshot of the wave shape.", "correct": False,
             "feedback": "Incorrect. That occurs when time is held fixed."},
            {"answer": "Uniform motion in space.", "correct": False,
             "feedback": "Incorrect. The motion is oscillatory."},
            {"answer": "Particle transport along the string.", "correct": False,
             "feedback": "Incorrect. The pattern moves, not the particles."}
        ]
    },

    {
        "question": (
            "Which quantity describes how rapidly a wave pattern repeats in space?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Wavelength", "correct": True,
             "feedback": "Correct. Wavelength sets spatial repetition."},
            {"answer": "Period", "correct": False,
             "feedback": "Incorrect. Period describes repetition in time."},
            {"answer": "Frequency", "correct": False,
             "feedback": "Incorrect. Frequency is temporal."},
            {"answer": "Amplitude", "correct": False,
             "feedback": "Incorrect. Amplitude measures size, not repetition."}
        ]
    },

    {
        "question": (
            "What does the phase speed of a wave represent?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "The speed at which a point of constant phase moves.", "correct": True,
             "feedback": "Correct. Phase speed tracks the motion of the pattern."},
            {"answer": "The speed of particles in the medium.", "correct": False,
             "feedback": "Incorrect. Particles typically oscillate in place."},
            {"answer": "The acceleration of the wave.", "correct": False,
             "feedback": "Incorrect. Acceleration is not defined for wave patterns here."},
            {"answer": "The rate at which energy is lost.", "correct": False,
             "feedback": "Incorrect. Phase speed is unrelated to dissipation."}
        ]
    },

    {
        "question": (
            "In a spatial snapshot y(x, t0), which quantity is held fixed?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Time", "correct": True,
             "feedback": "Correct. A snapshot fixes time and varies position."},
            {"answer": "Position", "correct": False,
             "feedback": "Incorrect. Position varies in a snapshot."},
            {"answer": "Phase", "correct": False,
             "feedback": "Incorrect. Phase varies with position."},
            {"answer": "Amplitude", "correct": False,
             "feedback": "Incorrect. Amplitude is a constant parameter."}
        ]
    },

    {
        "question": (
            "Which statement about frequency is correct?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "It tells how many oscillations occur per second.", "correct": True,
             "feedback": "Correct. Frequency measures temporal repetition."},
            {"answer": "It depends on position in the wave.", "correct": False,
             "feedback": "Incorrect. Frequency is the same everywhere."},
            {"answer": "It describes spatial repetition.", "correct": False,
             "feedback": "Incorrect. That is wavelength."},
            {"answer": "It changes as the wave propagates.", "correct": False,
             "feedback": "Incorrect. Frequency is set by the source."}
        ]
    },

    {
        "question": (
            "Why is angular frequency measured in radians per second?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Because oscillations can be described as steady phase progression.", "correct": True,
             "feedback": "Correct. Radians naturally measure phase."},
            {"answer": "Because the motion involves rotation.", "correct": False,
             "feedback": "Incorrect. No physical rotation is required."},
            {"answer": "Because meters are inconvenient.", "correct": False,
             "feedback": "Incorrect. Units reflect meaning, not convenience."},
            {"answer": "Because waves always travel in circles.", "correct": False,
             "feedback": "Incorrect. This is a geometric analogy, not motion."}
        ]
    },

    {
        "question": (
            "What determines the phase difference between two positions in a traveling wave?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "Their separation relative to the wavelength.", "correct": True,
             "feedback": "Correct. Phase difference depends on spatial separation."},
            {"answer": "Their mass.", "correct": False,
             "feedback": "Incorrect. Mass is irrelevant here."},
            {"answer": "Their speed.", "correct": False,
             "feedback": "Incorrect. Speed refers to the pattern, not positions."},
            {"answer": "The amplitude of the wave.", "correct": False,
             "feedback": "Incorrect. Amplitude does not affect phase."}
        ]
    },

    # =========================================================
    # Multiple Choice — Numeric (10)
    # =========================================================

    {
        "question": (
            "An oscillator has a period of 0.50 s. What is its frequency?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "2.0 Hz", "correct": True, "feedback": "Correct. f = 1/T = 2.0 Hz."},
            {"answer": "0.50 Hz", "correct": False, "feedback": "Incorrect. That is the period."},
            {"answer": "1.0 Hz", "correct": False, "feedback": "Incorrect. Recalculate 1/0.50."},
            {"answer": "4.0 Hz", "correct": False, "feedback": "Incorrect. That would require T = 0.25 s."}
        ]
    },

    {
        "question": (
            "A wave has wavelength 1.5 m and frequency 2.0 Hz. What is its phase speed?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "3.0 m/s", "correct": True, "feedback": "Correct. v = fλ = 3.0 m/s."},
            {"answer": "0.75 m/s", "correct": False, "feedback": "Incorrect. You divided instead of multiplied."},
            {"answer": "1.5 m/s", "correct": False, "feedback": "Incorrect. That equals λ only."},
            {"answer": "2.0 m/s", "correct": False, "feedback": "Incorrect. Check the formula."}
        ]
    },

    {
        "question": (
            "A wave has angular frequency 4π rad/s. What is its frequency?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "2.0 Hz", "correct": True, "feedback": "Correct. f = ω/(2π) = 2.0 Hz."},
            {"answer": "4.0 Hz", "correct": False, "feedback": "Incorrect. You forgot the 2π."},
            {"answer": "π Hz", "correct": False, "feedback": "Incorrect. Units are wrong."},
            {"answer": "8.0 Hz", "correct": False, "feedback": "Incorrect. Double check."}
        ]
    },

    {
        "question": (
            "A wave has wavenumber 2π rad/m. What is its wavelength?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "1.0 m", "correct": True, "feedback": "Correct. λ = 2π/k = 1.0 m."},
            {"answer": "2.0 m", "correct": False, "feedback": "Incorrect. That would be k = π."},
            {"answer": "π m", "correct": False, "feedback": "Incorrect. Check the relationship."},
            {"answer": "0.50 m", "correct": False, "feedback": "Incorrect. Inverse error."}
        ]
    },

    {
        "question": (
            "If a wave has period 0.25 s, what is its frequency?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "4.0 Hz", "correct": True, "feedback": "Correct. f = 1/T."},
            {"answer": "0.25 Hz", "correct": False, "feedback": "Incorrect. That is the period."},
            {"answer": "2.0 Hz", "correct": False, "feedback": "Incorrect. That would be T = 0.50 s."},
            {"answer": "8.0 Hz", "correct": False, "feedback": "Incorrect. That is too large."}
        ]
    },

    {
        "question": (
            "A wave travels at 6.0 m/s and has frequency 3.0 Hz. What is its wavelength?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "2.0 m", "correct": True, "feedback": "Correct. λ = v/f = 2.0 m."},
            {"answer": "18 m", "correct": False, "feedback": "Incorrect. You multiplied instead."},
            {"answer": "0.50 m", "correct": False, "feedback": "Incorrect. Inverse error."},
            {"answer": "6.0 m", "correct": False, "feedback": "Incorrect. That equals v only."}
        ]
    },

    {
        "question": (
            "An oscillation has frequency 10 Hz. What is its period?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "0.10 s", "correct": True, "feedback": "Correct. T = 1/f."},
            {"answer": "10 s", "correct": False, "feedback": "Incorrect. Inverse error."},
            {"answer": "0.01 s", "correct": False, "feedback": "Incorrect. That would be 100 Hz."},
            {"answer": "1.0 s", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": (
            "A wave has k = 10 rad/m. What is its wavelength?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "0.63 m", "correct": True, "feedback": "Correct. λ = 2π/10 ≈ 0.63 m."},
            {"answer": "0.10 m", "correct": False, "feedback": "Incorrect. Missing 2π."},
            {"answer": "6.3 m", "correct": False, "feedback": "Incorrect. Inverse error."},
            {"answer": "3.1 m", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": (
            "A wave repeats every 0.40 s. How many oscillations occur in 2.0 s?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "5", "correct": True, "feedback": "Correct. 2.0 / 0.40 = 5."},
            {"answer": "0.20", "correct": False, "feedback": "Incorrect. That is the frequency."},
            {"answer": "2.5", "correct": False, "feedback": "Incorrect. That is f, not count."},
            {"answer": "8", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": (
            "A wave has wavelength 0.50 m and period 0.25 s. What is its phase speed?"
        ),
        "type": "multiple_choice",
        "answers": [
            {"answer": "2.0 m/s", "correct": True, "feedback": "Correct. v = λ/T."},
            {"answer": "0.125 m/s", "correct": False, "feedback": "Incorrect. You multiplied T."},
            {"answer": "1.0 m/s", "correct": False, "feedback": "Incorrect."},
            {"answer": "4.0 m/s", "correct": False, "feedback": "Incorrect."}
        ]
    },

    # =========================================================
    # Numeric Entry — Single Value (10)
    # =========================================================

    {
        "question": (
            "A wave has wavelength 2.0 m and frequency 4.0 Hz.\n\n"
            "Enter the phase speed in m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 8.0, "correct": True, "feedback": "Correct. v = fλ = 8.0."},
            {"type": "range", "range": [7.84, 8.16], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 7.84], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [8.16, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "An oscillation has period 0.20 s.\n\n"
            "Enter the frequency in Hz."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 5.0, "correct": True, "feedback": "Correct. f = 1/T."},
            {"type": "range", "range": [4.9, 5.1], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 4.9], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [5.1, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave has angular frequency 6π rad/s.\n\n"
            "Enter the frequency in Hz."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 3.0, "correct": True, "feedback": "Correct. f = ω/(2π) = 3.0."},
            {"type": "range", "range": [2.94, 3.06], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 2.94], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [3.06, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave has wavenumber 4π rad/m.\n\n"
            "Enter the wavelength in meters."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 0.5, "correct": True, "feedback": "Correct. λ = 2π/k = 0.50."},
            {"type": "range", "range": [0.49, 0.51], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 0.49], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [0.51, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave repeats every 0.80 s.\n\n"
            "Enter the frequency in Hz."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 1.25, "correct": True, "feedback": "Correct. f = 1/0.80."},
            {"type": "range", "range": [1.22, 1.28], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 1.22], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [1.28, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave has wavelength 0.40 m and phase speed 2.0 m/s.\n\n"
            "Enter the period in seconds."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 0.20, "correct": True, "feedback": "Correct. T = λ/v."},
            {"type": "range", "range": [0.196, 0.204], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 0.196], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [0.204, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "An oscillation completes 8 cycles in 2.0 s.\n\n"
            "Enter the frequency in Hz."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 4.0, "correct": True, "feedback": "Correct. f = cycles/time."},
            {"type": "range", "range": [3.92, 4.08], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 3.92], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [4.08, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave has frequency 2.0 Hz and phase speed 6.0 m/s.\n\n"
            "Enter the wavelength in meters."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 3.0, "correct": True, "feedback": "Correct. λ = v/f."},
            {"type": "range", "range": [2.94, 3.06], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 2.94], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [3.06, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave has period 0.10 s.\n\n"
            "Enter the angular frequency in rad/s."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 62.8, "correct": True, "feedback": "Correct. ω = 2π/T ≈ 62.8."},
            {"type": "range", "range": [61.6, 64.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 61.6], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [64.0, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wave has wavelength 1.2 m and period 0.30 s.\n\n"
            "Enter the phase speed in m/s."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 4.0, "correct": True, "feedback": "Correct. v = λ/T."},
            {"type": "range", "range": [3.92, 4.08], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 3.92], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [4.08, 999], "correct": False, "feedback": "Too large."}
        ]
    },

]

display_quiz(quiz_D9)
# Out:
# <div id="ymypvlVAViRq" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...
