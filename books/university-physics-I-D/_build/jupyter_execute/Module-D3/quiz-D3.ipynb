# %% [markdown]
# ## D3.7 Interactive Self-Assessment Quiz
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
from jupyterquiz import display_quiz

quiz_D35 = [

    # -------------------------
    # Multiple Choice (20)
    # -------------------------

    {
        "question": (
            "A point particle model is most appropriate when...\n\n"
            "Choose the best statement."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "The object's size and shape do not affect the motion being analyzed.",
                "correct": True,
                "feedback": "Correct. If size/shape do not matter for the dynamics of interest, the point-particle model is appropriate."
            },
            {
                "answer": "The object literally has zero size and occupies no space.",
                "correct": False,
                "feedback": "Not correct. 'Point particle' is a modeling assumption, not a literal physical claim."
            },
            {
                "answer": "The object is microscopic (like an electron).",
                "correct": False,
                "feedback": "Not necessarily. Many macroscopic objects can be treated as point particles if size/shape do not matter."
            },
            {
                "answer": "The object experiences no forces.",
                "correct": False,
                "feedback": "Not correct. Point-particle modeling is about ignoring size/shape, not about eliminating forces."
            }
        ]
    },

    {
        "question": (
            "In 1D motion, which statement best describes the difference between speed and velocity"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Speed has no direction; velocity includes direction through a sign (+/-).",
                "correct": True,
                "feedback": "Correct. In 1D, direction is encoded by the sign of the velocity."
            },
            {
                "answer": "Speed is always positive; velocity is always negative.",
                "correct": False,
                "feedback": "Not correct. Velocity can be positive or negative depending on direction."
            },
            {
                "answer": "Speed and velocity mean the same thing in physics.",
                "correct": False,
                "feedback": "Not correct. Speed is magnitude only; velocity is signed in 1D."
            },
            {
                "answer": "Velocity is measured in newtons; speed is measured in m/s.",
                "correct": False,
                "feedback": "Not correct. Both speed and velocity use units of m/s."
            }
        ]
    },

    {
        "question": (
            "In this course’s 1D convention, the subscript in p_x and v_x primarily reminds you that..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "These quantities carry a sense of direction (sign) along the x-axis.",
                "correct": True,
                "feedback": "Correct. The x-subscript highlights direction in 1D via +/-."
            },
            {
                "answer": "These quantities are always positive.",
                "correct": False,
                "feedback": "Not correct. They can be positive or negative."
            },
            {
                "answer": "These quantities are measured in kilograms.",
                "correct": False,
                "feedback": "Not correct. Momentum is kg·m/s and velocity is m/s."
            },
            {
                "answer": "These quantities do not depend on time.",
                "correct": False,
                "feedback": "Not correct. They can change with time due to interactions."
            }
        ]
    },

    {
        "question": (
            "Which quantity below is not associated with direction in 1D (so it does not need a subscript x)?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Mass, m",
                "correct": True,
                "feedback": "Correct. Mass is not directional."
            },
            {
                "answer": "Velocity, v_x",
                "correct": False,
                "feedback": "Not correct. Velocity is directional in 1D."
            },
            {
                "answer": "Momentum, p_x",
                "correct": False,
                "feedback": "Not correct. Momentum is directional in 1D."
            },
            {
                "answer": "Impulse, j_x",
                "correct": False,
                "feedback": "Not correct. Impulse is directional in 1D."
            }
        ]
    },

    {
        "question": (
            "Which statement best defines impulse for a single point particle in 1D?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Impulse is the momentum transferred: j_x = \u0394p_x.",
                "correct": True,
                "feedback": "Correct. Impulse is defined as the change in momentum."
            },
            {
                "answer": "Impulse is the momentum itself: j_x = p_x.",
                "correct": False,
                "feedback": "Not correct. Impulse is a change in momentum, not momentum itself."
            },
            {
                "answer": "Impulse is the distance traveled during a push.",
                "correct": False,
                "feedback": "Not correct. That relates more to work concepts, not impulse."
            },
            {
                "answer": "Impulse is always zero if an object is moving.",
                "correct": False,
                "feedback": "Not correct. Moving objects can experience impulses that change their momentum."
            }
        ]
    },

    {
        "question": (
            "A particle’s momentum changes from p_{x,i} to p_{x,f}. The impulse is..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "j_x = p_{x,f} - p_{x,i}",
                "correct": True,
                "feedback": "Correct. Impulse is the change in momentum."
            },
            {
                "answer": "j_x = p_{x,f} + p_{x,i}",
                "correct": False,
                "feedback": "Not correct. That would add momenta, not find the change."
            },
            {
                "answer": "j_x = p_{x,i} - p_{x,f}",
                "correct": False,
                "feedback": "Not correct. Sign is reversed."
            },
            {
                "answer": "j_x = p_{x,f}/p_{x,i}",
                "correct": False,
                "feedback": "Not correct. Impulse is not a ratio of momenta."
            }
        ]
    },

    {
        "question": (
            "Which statement is most correct about momentum and momentum change for different observers moving at constant relative speed?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Different observers can disagree on momentum, but they agree on the momentum change caused by an interaction.",
                "correct": True,
                "feedback": "Correct. Momentum depends on the observer, but the change from an interaction is agreed upon in this Newtonian context."
            },
            {
                "answer": "All observers always measure the same momentum for the same object.",
                "correct": False,
                "feedback": "Not correct. Momentum depends on measured velocity, which depends on the observer."
            },
            {
                "answer": "All observers always measure the same velocity for the same object.",
                "correct": False,
                "feedback": "Not correct. Velocity depends on the observer’s motion."
            },
            {
                "answer": "Momentum change depends on the observer, so it is not useful in physics.",
                "correct": False,
                "feedback": "Not correct. Momentum change from an interaction is a central, reliable quantity."
            }
        ]
    },

    {
        "question": (
            "If a constant force f_x acts over a time interval \u0394t, the impulse is..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "j_x = f_x \u0394t",
                "correct": True,
                "feedback": "Correct. Constant (or average) force times time gives impulse."
            },
            {
                "answer": "j_x = f_x/\u0394t",
                "correct": False,
                "feedback": "Not correct. That would have incorrect units."
            },
            {
                "answer": "j_x = \u0394t/f_x",
                "correct": False,
                "feedback": "Not correct. Units would not match impulse."
            },
            {
                "answer": "j_x = f_x \u0394x",
                "correct": False,
                "feedback": "Not correct. Force times displacement relates to work, not impulse."
            }
        ]
    },

    {
        "question": (
            "The SI unit of force is the newton (N). Which is the correct base-unit form?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "N = {kg·m}/{s^2}",
                "correct": True,
                "feedback": "Correct."
            },
            {
                "answer": "N = kg·m/s",
                "correct": False,
                "feedback": "Not correct. That is the unit of momentum (and impulse), not force."
            },
            {
                "answer": "N = {kg}/{s^2}",
                "correct": False,
                "feedback": "Not correct. Missing meters."
            },
            {
                "answer": "N = m/s",
                "correct": False,
                "feedback": "Not correct. That is the unit of velocity."
            }
        ]
    },

    {
        "question": (
            "On a force–time graph (f_x vs. t), the impulse delivered over a time interval equals..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "The signed area under the curve.",
                "correct": True,
                "feedback": "Correct. Impulse is the area under the force–time curve (with sign)."
            },
            {
                "answer": "The slope of the curve.",
                "correct": False,
                "feedback": "Not correct. Slope is not impulse."
            },
            {
                "answer": "The highest force value on the graph.",
                "correct": False,
                "feedback": "Not correct. Peak force alone does not determine impulse."
            },
            {
                "answer": "The time at which the force is maximum.",
                "correct": False,
                "feedback": "Not correct. Impulse depends on the whole curve."
            }
        ]
    },

    {
        "question": (
            "A force–time graph lies entirely below the time axis (negative f_x). The impulse over that interval is..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Negative.",
                "correct": True,
                "feedback": "Correct. Signed area below the axis is negative."
            },
            {
                "answer": "Positive.",
                "correct": False,
                "feedback": "Not correct. Area below the axis gives negative impulse."
            },
            {
                "answer": "Zero.",
                "correct": False,
                "feedback": "Not correct. Zero impulse would require zero net area."
            },
            {
                "answer": "Undefined.",
                "correct": False,
                "feedback": "Not correct. Impulse is well-defined as area under the curve."
            }
        ]
    },

    {
        "question": (
            "Net impulse from multiple forces is best described by which statement?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Net impulse is the sum of individual impulses: j_{net,x} = sum j_x.",
                "correct": True,
                "feedback": "Correct. Always start with summing impulses."
            },
            {
                "answer": "Net impulse is always sum (f_x \u0394t) even if forces act for different times.",
                "correct": False,
                "feedback": "Not correct. You can only factor out one Δt if the forces act over the same time interval."
            },
            {
                "answer": "Net impulse depends only on the largest force.",
                "correct": False,
                "feedback": "Not correct. Impulse depends on force and duration (area)."
            },
            {
                "answer": "Net impulse is the same as net force.",
                "correct": False,
                "feedback": "Not correct. Net impulse includes time; net force does not."
            }
        ]
    },

    {
        "question": (
            "Which condition is required to use j_{net,x} = f_{net,x} \u0394t directly?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "All contributing forces act over the same time interval \u0394t (or share a common interval).",
                "correct": True,
                "feedback": "Correct. Otherwise you must sum impulses over each force’s own duration."
            },
            {
                "answer": "All forces must be positive.",
                "correct": False,
                "feedback": "Not correct. Forces can be positive or negative."
            },
            {
                "answer": "The object must be at rest initially.",
                "correct": False,
                "feedback": "Not correct. Initial motion does not determine whether the formula applies."
            },
            {
                "answer": "The mass must be 1 kg.",
                "correct": False,
                "feedback": "Not correct. Mass does not need to be 1 kg."
            }
        ]
    },

    {
        "question": (
            "Why do internal impulses cancel when summing over a two-particle system during an interaction?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Newton’s Third Law gives equal-and-opposite internal forces acting over the same interaction time.",
                "correct": True,
                "feedback": "Correct. Equal-and-opposite forces over the same time give equal-and-opposite impulses."
            },
            {
                "answer": "Because internal forces are always zero.",
                "correct": False,
                "feedback": "Not correct. Internal forces are typically nonzero during interactions."
            },
            {
                "answer": "Because masses are equal.",
                "correct": False,
                "feedback": "Not correct. Cancellation does not require equal masses."
            },
            {
                "answer": "Because velocity is the same for both particles.",
                "correct": False,
                "feedback": "Not correct. Particles can have different velocities."
            }
        ]
    },

    {
        "question": (
            "Conservation of momentum for a system is guaranteed when..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "The net external impulse on the system is zero.",
                "correct": True,
                "feedback": "Correct. Zero external impulse means total system momentum stays constant."
            },
            {
                "answer": "The net internal impulse on the system is zero.",
                "correct": False,
                "feedback": "Not correct. Internal impulse cancellation happens automatically, but conservation requires zero external impulse."
            },
            {
                "answer": "The net external force is zero at one instant.",
                "correct": False,
                "feedback": "Not correct. Conservation depends on net external impulse over the interaction time, not a single instant."
            },
            {
                "answer": "Both objects have the same mass.",
                "correct": False,
                "feedback": "Not correct. Conservation does not require equal masses."
            }
        ]
    },

    {
        "question": (
            "In 1D, if p_x is negative, that most directly means..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "The particle’s motion is in the negative x-direction.",
                "correct": True,
                "feedback": "Correct. Sign indicates direction along the chosen axis."
            },
            {
                "answer": "The particle has negative mass.",
                "correct": False,
                "feedback": "Not correct. Mass is positive in this course."
            },
            {
                "answer": "The particle is slowing down.",
                "correct": False,
                "feedback": "Not necessarily. Negative momentum can be speeding up or slowing down depending on the situation."
            },
            {
                "answer": "The particle’s speed must be zero.",
                "correct": False,
                "feedback": "Not correct. Negative momentum can have nonzero speed."
            }
        ]
    },

    {
        "question": (
            "Which statement best contrasts impulse–momentum with work–energy?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Impulse involves force acting through time; work involves force acting through displacement.",
                "correct": True,
                "feedback": "Correct. This difference is why momentum conservation behaves differently than energy accounting."
            },
            {
                "answer": "Impulse and work are the same quantity with different names.",
                "correct": False,
                "feedback": "Not correct. They are fundamentally different."
            },
            {
                "answer": "Impulse depends on displacement; work depends on time.",
                "correct": False,
                "feedback": "Not correct. It’s the opposite."
            },
            {
                "answer": "Impulse has units of joules; work has units of newtons.",
                "correct": False,
                "feedback": "Not correct. Impulse has units of kg·m/s, work has units of joules."
            }
        ]
    },

    {
        "question": (
            "A force–time curve is approximated by many small rectangles and their areas are summed. This procedure is most closely related to..."
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "Riemann sums (numerical integration idea).",
                "correct": True,
                "feedback": "Correct. Summing small rectangle areas approximates the total area under a curve."
            },
            {
                "answer": "Solving quadratic equations.",
                "correct": False,
                "feedback": "Not correct."
            },
            {
                "answer": "Finding a slope using two points.",
                "correct": False,
                "feedback": "Not correct."
            },
            {
                "answer": "Unit conversion using factor–label.",
                "correct": False,
                "feedback": "Not correct."
            }
        ]
    },

    {
        "question": (
            "Which equation is the standard working form of 1D momentum conservation for two particles?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "m_1 v_{1,x,i} + m_2 v_{2,x,i} = m_1 v_{1,x,f} + m_2 v_{2,x,f}",
                "correct": True,
                "feedback": "Correct. This is the plug-in equation used for most two-particle 1D problems."
            },
            {
                "answer": "m_1 v_{1,x,i} - m_2 v_{2,x,i} = m_1 v_{1,x,f} - m_2 v_{2,x,f}",
                "correct": False,
                "feedback": "Not correct. Signs must come from the velocities, not built into the formula."
            },
            {
                "answer": "m_1 + m_2 = m_1 v_{1,x,f} + m_2 v_{2,x,f}",
                "correct": False,
                "feedback": "Not correct. Left side has units of mass, not momentum."
            },
            {
                "answer": "v_{1,x,i} + v_{2,x,i} = v_{1,x,f} + v_{2,x,f}",
                "correct": False,
                "feedback": "Not correct. Conservation involves momentum, not velocity sums."
            }
        ]
    },

        {
        "question": (
            "A 2.0 kg cart moves in the +x direction at 3.0 m/s.\n\n"
            "What is the cart’s momentum p_x?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "+6.0 kg·m/s",
                "correct": True,
                "feedback": "Correct. p_x = m v_x = (2.0)(+3.0) = +6.0 kg·m/s."
            },
            {
                "answer": "-6.0 kg·m/s",
                "correct": False,
                "feedback": "Incorrect sign. The cart is moving in the +x direction."
            },
            {
                "answer": "+1.5 kg·m/s",
                "correct": False,
                "feedback": "Incorrect magnitude. Check the multiplication."
            },
            {
                "answer": "+5.0 kg·m/s",
                "correct": False,
                "feedback": "Not correct. Recalculate p = m v."
            }
        ]
    },

    {
        "question": (
            "A 0.50 kg particle changes velocity from +4.0 m/s to -2.0 m/s.\n\n"
            "What is the impulse j_x delivered to the particle?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "-3.0 kg·m/s",
                "correct": True,
                "feedback": "Correct. j_x = m(v_f - v_i) = 0.50(-2.0 - 4.0) = -3.0 kg·m/s."
            },
            {
                "answer": "+3.0 kg·m/s",
                "correct": False,
                "feedback": "Incorrect sign. The momentum change is negative."
            },
            {
                "answer": "-1.0 kg·m/s",
                "correct": False,
                "feedback": "Incorrect magnitude. Recheck the velocity change."
            },
            {
                "answer": "-6.0 kg·m/s",
                "correct": False,
                "feedback": "Incorrect. You likely forgot to multiply by mass."
            }
        ]
    },

    {
        "question": (
            "A constant force of -4.0 N acts on a particle for 0.25 s.\n\n"
            "What impulse is delivered?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "-1.0 kg·m/s",
                "correct": True,
                "feedback": "Correct. j_x = f_x \u0394t = (-4.0)(0.25) = -1.0 kg·m/s."
            },
            {
                "answer": "+1.0 kg·m/s",
                "correct": False,
                "feedback": "Incorrect sign. Force is in the negative x-direction."
            },
            {
                "answer": "-16 kg·m/s",
                "correct": False,
                "feedback": "Incorrect. You multiplied instead of multiplying by time."
            },
            {
                "answer": "-0.50 kg·m/s",
                "correct": False,
                "feedback": "Not correct. Check the time interval."
            }
        ]
    },

    {
        "question": (
            "A triangular force–time pulse has a base of 0.20 s and a height of 300 N.\n\n"
            "What impulse does it deliver?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "30 kg·m/s",
                "correct": True,
                "feedback": "Correct. j = ½(0.20)(300) = 30 kg·m/s."
            },
            {
                "answer": "60 kg·m/s",
                "correct": False,
                "feedback": "Incorrect. You forgot the ½ factor."
            },
            {
                "answer": "15 kg·m/s",
                "correct": False,
                "feedback": "Incorrect. Check the base and height values."
            },
            {
                "answer": "300 kg·m/s",
                "correct": False,
                "feedback": "Incorrect. That would ignore the time duration."
            }
        ]
    },

    {
        "question": (
            "Two carts interact on a frictionless track.\n\n"
            "m₁ = 1.0 kg with v₁,i = +4.0 m/s\n"
            "m₂ = 2.0 kg initially at rest\n"
            "After the interaction, v₁,f = +1.0 m/s.\n\n"
            "What is v₂,f?"
        ),
        "type": "multiple_choice",
        "answers": [
            {
                "answer": "+1.5 m/s",
                "correct": True,
                "feedback": "Correct. Momentum conservation gives v₂,f = +1.5 m/s."
            },
            {
                "answer": "+3.0 m/s",
                "correct": False,
                "feedback": "Incorrect. That would violate momentum conservation."
            },
            {
                "answer": "-1.5 m/s",
                "correct": False,
                "feedback": "Incorrect sign. The total momentum is positive."
            },
            {
                "answer": "+0.75 m/s",
                "correct": False,
                "feedback": "Not correct. Recheck the algebra."
            }
        ]
    },



    # -------------------------
    # Numeric (10)
    # -------------------------

    {
        "question": (
            "Compute the momentum p_x.\n\n"
            "A 1.5 kg particle moves with velocity v_x = -4.0 m/s.\n\n"
            "Enter p_x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": -6.0, "correct": True, "feedback": "Correct. p_x = m v_x = (1.5)(-4.0) = -6.0 kg·m/s."},
            {"type": "range", "range": [-6.12, -5.88], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, -6.12], "correct": False, "feedback": "Too negative. Recheck multiplication and sign."},
            {"type": "range", "range": [-5.88, 999], "correct": False, "feedback": "Not correct. Check sign and magnitude."}
        ]
    },

    {
        "question": (
            "Compute the impulse j_x.\n\n"
            "A 0.20 kg particle changes velocity from +10 m/s to 0 m/s.\n\n"
            "Enter j_x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": -2.0, "correct": True, "feedback": "Correct. j_x = Δp_x = m(v_f - v_i) = 0.20(0-10) = -2.0."},
            {"type": "range", "range": [-2.04, -1.96], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, -2.04], "correct": False, "feedback": "Too negative. Check arithmetic."},
            {"type": "range", "range": [-1.96, 999], "correct": False, "feedback": "Not correct. Check sign and Δv."}
        ]
    },

    {
        "question": (
            "A constant force f_x = -3.0 N acts for \u0394t = 0.50 s.\n\n"
            "Compute the impulse j_x = f_x \u0394t.\n\n"
            "Enter j_x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": -1.5, "correct": True, "feedback": "Correct. j_x = (-3.0)(0.50) = -1.5 kg·m/s."},
            {"type": "range", "range": [-1.53, -1.47], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, -1.53], "correct": False, "feedback": "Too negative. Check multiplication."},
            {"type": "range", "range": [-1.47, 999], "correct": False, "feedback": "Not correct. Check sign and Δt."}
        ]
    },

    {
        "question": (
            "A force increases linearly from 2 N to 6 N over 1.0 s.\n\n"
            "Approximate the impulse using the trapezoid area.\n\n"
            "Enter j_x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 4.0, "correct": True, "feedback": "Correct. Average force is (2+6)/2=4 N, so j_x = 4(1.0)=4."},
            {"type": "range", "range": [3.92, 4.08], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, 3.92], "correct": False, "feedback": "Too small. Check trapezoid/average force idea."},
            {"type": "range", "range": [4.08, 999], "correct": False, "feedback": "Too large. Check average force and Δt."}
        ]
    },

    {
        "question": (
            "A triangular force–time pulse has base 0.20 s and height 500 N.\n\n"
            "Compute the impulse (area).\n\n"
            "Enter j_x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 50.0, "correct": True, "feedback": "Correct. j_x = 0.5(0.20)(500)=50 kg·m/s."},
            {"type": "range", "range": [49.0, 51.0], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, 49.0], "correct": False, "feedback": "Too small. Check triangle area."},
            {"type": "range", "range": [51.0, 999], "correct": False, "feedback": "Too large. Check base/height."}
        ]
    },

    {
        "question": (
            "A 0.50 kg particle has initial velocity v_{x,i}=+2.0 m/s.\n\n"
            "An impulse j_x = -1.0 kg·m/s acts.\n\n"
            "Find the final velocity.\n\n"
            "Enter v_{x,f} in m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 0.0, "correct": True, "feedback": "Correct. p_i=0.5*2=1; p_f=1-1=0; v_f=0/0.5=0."},
            {"type": "range", "range": [-0.02, 0.02], "correct": True, "feedback": "Correct. Near zero within tolerance."},
            {"type": "range", "range": [-999, -0.02], "correct": False, "feedback": "Not correct. Check p_f = p_i + j_x."},
            {"type": "range", "range": [0.02, 999], "correct": False, "feedback": "Not correct. Check p_f = p_i + j_x."}
        ]
    },

    {
        "question": (
            "Two-particle momentum conservation.\n\n"
            "m1=1.0 kg, v1_i=+3.0 m/s\n"
            "m2=2.0 kg, v2_i=-1.0 m/s\n"
            "After: v1_f=+0.50 m/s\n\n"
            "Find v2_f.\n\n"
            "Enter v2_f in m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 0.25, "correct": True, "feedback": "Correct. P_i=3-2=1; 1=0.5+2v2_f => v2_f=0.25."},
            {"type": "range", "range": [0.245, 0.255], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, 0.245], "correct": False, "feedback": "Too small. Check conservation equation."},
            {"type": "range", "range": [0.255, 999], "correct": False, "feedback": "Too large. Check algebra."}
        ]
    },

    {
        "question": (
            "Net impulse from multiple forces over the same time interval.\n\n"
            "For \u0394t = 0.40 s, forces are: +6.0 N, -4.0 N, -1.0 N.\n\n"
            "Compute the net impulse j_net,x.\n\n"
            "Enter j_net,x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 0.40, "correct": True, "feedback": "Correct. f_net=+1 N, so j_net=1(0.40)=0.40."},
            {"type": "range", "range": [0.392, 0.408], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, 0.392], "correct": False, "feedback": "Too small. Check net force and Δt."},
            {"type": "range", "range": [0.408, 999], "correct": False, "feedback": "Too large. Check net force and Δt."}
        ]
    },

    {
        "question": (
            "Force unit check.\n\n"
            "A net impulse of 6.0 kg·m/s is delivered over 0.50 s.\n\n"
            "Compute the average net force magnitude.\n\n"
            "Enter f_net in newtons (N). A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 12.0, "correct": True, "feedback": "Correct. f = j/Δt = 6.0/0.50 = 12 N."},
            {"type": "range", "range": [11.76, 12.24], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, 11.76], "correct": False, "feedback": "Too small. Check division by Δt."},
            {"type": "range", "range": [12.24, 999], "correct": False, "feedback": "Too large. Check division by Δt."}
        ]
    },

    {
        "question": (
            "Impulse from a force–time graph (rectangle).\n\n"
            "A constant force of 5.0 N acts for 0.40 s.\n\n"
            "Compute the impulse (area).\n\n"
            "Enter j_x in kg·m/s. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 2.0, "correct": True, "feedback": "Correct. j = FΔt = 5.0(0.40) = 2.0."},
            {"type": "range", "range": [1.96, 2.04], "correct": True, "feedback": "Correct. Within 2% tolerance."},
            {"type": "range", "range": [-999, 1.96], "correct": False, "feedback": "Too small. Check rectangle area."},
            {"type": "range", "range": [2.04, 999], "correct": False, "feedback": "Too large. Check rectangle area."}
        ]
    },

]

display_quiz(quiz_D35)
# Out:
# <div id="eZWrXbpVFeim" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...
