# %% [markdown]
# # D7.7 Interactive Self-Assessment Quiz
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %%
from jupyterquiz import display_quiz

quiz_D7 = [

    # =========================================================
    # Multiple Choice — Conceptual / Word Problems (10)
    # =========================================================

    {
        "question": "Which statement best describes temperature?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "A measure of the average thermal motion of particles in a system.", "correct": True,
             "feedback": "Correct. Temperature reflects average microscopic motion."},
            {"answer": "The total thermal energy contained in an object.", "correct": False,
             "feedback": "Incorrect. That is closer to internal energy, not temperature."},
            {"answer": "Energy transferred due to a temperature difference.", "correct": False,
             "feedback": "Incorrect. That describes heat."},
            {"answer": "A subjective sensation of hot and cold.", "correct": False,
             "feedback": "Incorrect. Sensation is subjective; temperature is objective."}
        ]
    },

    {
        "question": "Heat is best defined as:",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Energy transferred because of a temperature difference.", "correct": True,
             "feedback": "Correct."},
            {"answer": "Energy stored inside a system.", "correct": False,
             "feedback": "Incorrect. That is internal energy."},
            {"answer": "A state variable that depends only on temperature.", "correct": False,
             "feedback": "Incorrect. Heat is not a state variable."},
            {"answer": "A property of a substance like density or conductivity.", "correct": False,
             "feedback": "Incorrect. Heat is a transfer process, not a material property."}
        ]
    },

    {
        "question": "Which quantity is a state variable?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Internal energy U", "correct": True,
             "feedback": "Correct. U depends only on the state."},
            {"answer": "Heat Q", "correct": False,
             "feedback": "Incorrect. Q depends on the process."},
            {"answer": "Work W", "correct": False,
             "feedback": "Incorrect. W depends on the process."},
            {"answer": "Heat-transfer rate Q/t", "correct": False,
             "feedback": "Incorrect. A rate is not a state variable."}
        ]
    },

    {
        "question": "With the physics convention used in this course, the First Law is:",
        "type": "multiple_choice",
        "answers": [
            {"answer": "ΔU = Q − W", "correct": True,
             "feedback": "Correct. W is work done by the system."},
            {"answer": "ΔU = Q + W", "correct": False,
             "feedback": "Incorrect. That corresponds to a different work sign convention."},
            {"answer": "ΔU = W − Q", "correct": False,
             "feedback": "Incorrect. Signs are reversed."},
            {"answer": "ΔU = Q/W", "correct": False,
             "feedback": "Incorrect. Not a valid energy equation."}
        ]
    },

    {
        "question": "In this course’s sign convention, W > 0 means:",
        "type": "multiple_choice",
        "answers": [
            {"answer": "The system does work on the surroundings (e.g., expansion).", "correct": True,
             "feedback": "Correct."},
            {"answer": "The surroundings do work on the system (e.g., compression).", "correct": False,
             "feedback": "Incorrect. That would be W < 0 in this course."},
            {"answer": "Heat flows into the system.", "correct": False,
             "feedback": "Incorrect. That describes Q > 0."},
            {"answer": "The system’s temperature must increase.", "correct": False,
             "feedback": "Incorrect. Work can occur with different temperature outcomes."}
        ]
    },

    {
        "question": "During melting at 0°C (ice → water) at 1 atm, which is true?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Temperature stays constant while energy is transferred.", "correct": True,
             "feedback": "Correct. Energy goes into changing phase, not raising T."},
            {"answer": "Temperature increases steadily with added heat.", "correct": False,
             "feedback": "Incorrect. That happens outside phase change."},
            {"answer": "No heat transfer occurs.", "correct": False,
             "feedback": "Incorrect. Heat transfer is required to melt."},
            {"answer": "Internal energy stays constant.", "correct": False,
             "feedback": "Incorrect. Internal energy changes during phase change."}
        ]
    },

    {
        "question": "Which mechanism requires bulk motion of a fluid (liquid or gas)?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Convection", "correct": True,
             "feedback": "Correct."},
            {"answer": "Conduction", "correct": False,
             "feedback": "Incorrect. Conduction does not require bulk motion."},
            {"answer": "Radiation", "correct": False,
             "feedback": "Incorrect. Radiation does not require a medium."},
            {"answer": "Thermal expansion", "correct": False,
             "feedback": "Incorrect. Expansion is not a heat-transfer mechanism."}
        ]
    },

    {
        "question": "Which heat-transfer mechanism can occur through a vacuum?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Radiation", "correct": True,
             "feedback": "Correct."},
            {"answer": "Conduction", "correct": False,
             "feedback": "Incorrect. Conduction needs matter."},
            {"answer": "Convection", "correct": False,
             "feedback": "Incorrect. Convection needs a fluid."},
            {"answer": "All of them", "correct": False,
             "feedback": "Incorrect. Only radiation works without matter."}
        ]
    },

    {
        "question": "Why do metals often feel colder than wood at the same room temperature?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Metals conduct heat away from your skin faster.", "correct": True,
             "feedback": "Correct. The sensation relates to heat-transfer rate."},
            {"answer": "Metals have a lower temperature than wood in the same room.", "correct": False,
             "feedback": "Incorrect. They can be at the same temperature."},
            {"answer": "Metals contain less internal energy than wood.", "correct": False,
             "feedback": "Incorrect. Internal energy depends on many factors."},
            {"answer": "Wood radiates heat more effectively than metal.", "correct": False,
             "feedback": "Incorrect. The dominant effect here is conduction to your skin."}
        ]
    },

    {
        "question": "Latent heat is energy used to:",
        "type": "multiple_choice",
        "answers": [
            {"answer": "Change phase without changing temperature.", "correct": True,
             "feedback": "Correct."},
            {"answer": "Increase temperature without changing phase.", "correct": False,
             "feedback": "Incorrect. That uses specific heat."},
            {"answer": "Transfer energy only by radiation.", "correct": False,
             "feedback": "Incorrect. Latent heat is not a transfer mode."},
            {"answer": "Prevent thermal expansion.", "correct": False,
             "feedback": "Incorrect."}
        ]
    },

    # =========================================================
    # Multiple Choice — Numeric Options (10)
    # =========================================================

    {
        "question": "Convert 42°C to °F (use T_F = (9/5)T_C + 32).",
        "type": "multiple_choice",
        "answers": [
            {"answer": "108°F", "correct": True, "feedback": "Correct."},
            {"answer": "74°F", "correct": False, "feedback": "Incorrect. That is too low."},
            {"answer": "122°F", "correct": False, "feedback": "Incorrect. Recheck the formula."},
            {"answer": "96°F", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "A temperature change of 20 K corresponds to what change in °F?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "36°F", "correct": True, "feedback": "Correct. ΔT_F = (9/5)ΔT_C = (9/5)ΔT_K."},
            {"answer": "20°F", "correct": False, "feedback": "Incorrect. °F increments are smaller than °C/K."},
            {"answer": "11°F", "correct": False, "feedback": "Incorrect."},
            {"answer": "68°F", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "Liquid nitrogen boils at 77 K. What is this in Rankine? (T_R = (9/5)T_K)",
        "type": "multiple_choice",
        "answers": [
            {"answer": "139 R", "correct": True, "feedback": "Correct. 1.8×77 = 138.6 R."},
            {"answer": "77 R", "correct": False, "feedback": "Incorrect. Rankine uses Fahrenheit-sized degrees."},
            {"answer": "154 R", "correct": False, "feedback": "Incorrect."},
            {"answer": "430 R", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "How much heat is needed to warm 0.50 kg of water by 10 K? (c = 4186 J/(kg·K))",
        "type": "multiple_choice",
        "answers": [
            {"answer": "2.09×10^4 J", "correct": True, "feedback": "Correct. Q = mcΔT = 0.5×4186×10."},
            {"answer": "4.19×10^4 J", "correct": False, "feedback": "Incorrect. That would be for 1.0 kg."},
            {"answer": "2.09×10^3 J", "correct": False, "feedback": "Incorrect."},
            {"answer": "8.37×10^4 J", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "How much heat is required to melt 0.20 kg of ice at 0°C? (L_f = 3.34×10^5 J/kg)",
        "type": "multiple_choice",
        "answers": [
            {"answer": "6.68×10^4 J", "correct": True, "feedback": "Correct. Q = mL."},
            {"answer": "3.34×10^5 J", "correct": False, "feedback": "Incorrect. That is for 1.0 kg."},
            {"answer": "1.67×10^5 J", "correct": False, "feedback": "Incorrect."},
            {"answer": "6.68×10^5 J", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "How much heat is needed to vaporize 0.10 kg of water at 100°C? (L_v = 2.26×10^6 J/kg)",
        "type": "multiple_choice",
        "answers": [
            {"answer": "2.26×10^5 J", "correct": True, "feedback": "Correct. Q = mL_v."},
            {"answer": "2.26×10^6 J", "correct": False, "feedback": "Incorrect. That is for 1.0 kg."},
            {"answer": "4.52×10^5 J", "correct": False, "feedback": "Incorrect."},
            {"answer": "2.26×10^4 J", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "A wall has R_total = 0.20 K/W and ΔT = 25 K. What is the conduction heat-loss rate Q/t?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "125 W", "correct": True, "feedback": "Correct. Q/t = ΔT/R."},
            {"answer": "5.0 W", "correct": False, "feedback": "Incorrect."},
            {"answer": "0.008 W", "correct": False, "feedback": "Incorrect."},
            {"answer": "500 W", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "A surface has h = 10 W/(m^2·K), area A = 5.0 m^2, and ΔT = 12 K. What is convective heat-loss rate?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "600 W", "correct": True, "feedback": "Correct. Q/t = hAΔT."},
            {"answer": "60 W", "correct": False, "feedback": "Incorrect. Missed a factor of 10."},
            {"answer": "120 W", "correct": False, "feedback": "Incorrect."},
            {"answer": "2400 W", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "A surface (ε=1) with area 1.0 m^2 at T = 300 K radiates approximately what power? (σ = 5.67×10^-8)",
        "type": "multiple_choice",
        "answers": [
            {"answer": "460 W", "correct": True, "feedback": "Correct. P = σAT^4 ≈ 5.67e-8×(300^4) ≈ 459 W."},
            {"answer": "46 W", "correct": False, "feedback": "Incorrect. Off by 10×."},
            {"answer": "4600 W", "correct": False, "feedback": "Incorrect. Off by 10×."},
            {"answer": "5.7 W", "correct": False, "feedback": "Incorrect."}
        ]
    },

    {
        "question": "A system absorbs Q = 500 J of heat and does W = 200 J of work. What is ΔU?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "300 J", "correct": True, "feedback": "Correct. ΔU = Q − W = 500 − 200."},
            {"answer": "700 J", "correct": False, "feedback": "Incorrect. That would be Q + W."},
            {"answer": "-300 J", "correct": False, "feedback": "Incorrect. Sign error."},
            {"answer": "-700 J", "correct": False, "feedback": "Incorrect."}
        ]
    },

    # =========================================================
    # Numeric Entry — Student Input (10)
    # =========================================================

    {
        "question": (
            "Convert 25.0°C to °F.\n\n"
            "Enter the temperature in °F. A 1% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 77.0, "correct": True, "feedback": "Correct. 25°C = 77°F."},
            {"type": "range", "range": [76.23, 77.77], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 76.23], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [77.77, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A temperature change of 15.0 K corresponds to what change in Rankine?\n\n"
            "Enter ΔT_R in R. A 1% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 27.0, "correct": True, "feedback": "Correct. ΔT_R = (9/5)ΔT_K = 27."},
            {"type": "range", "range": [26.73, 27.27], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 26.73], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [27.27, 999], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "How much heat is required to warm 0.250 kg of water by 20.0 K? (c = 4186 J/(kg·K))\n\n"
            "Enter Q in joules. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 20930.0, "correct": True, "feedback": "Correct. Q = mcΔT."},
            {"type": "range", "range": [20411.4, 21448.6], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 20411.4], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [21448.6, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "How much heat is required to melt 0.300 kg of ice at 0°C? (L_f = 3.34×10^5 J/kg)\n\n"
            "Enter Q in joules. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 100200.0, "correct": True, "feedback": "Correct. Q = mL_f."},
            {"type": "range", "range": [98196.0, 102204.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 98196.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [102204.0, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "How much heat is required to vaporize 0.0800 kg of water at 100°C? (L_v = 2.26×10^6 J/kg)\n\n"
            "Enter Q in joules. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 180800.0, "correct": True, "feedback": "Correct. Q = mL_v."},
            {"type": "range", "range": [177184.0, 184416.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 177184.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [184416.0, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A wall has total thermal resistance R_tot = 0.250 K/W and ΔT = 30.0 K.\n\n"
            "Enter the conduction heat-loss rate Q/t in watts. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 120.0, "correct": True, "feedback": "Correct. Q/t = ΔT/R_tot."},
            {"type": "range", "range": [117.6, 122.4], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 117.6], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [122.4, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "Convection: h = 12.0 W/(m^2·K), A = 8.00 m^2, ΔT = 10.0 K.\n\n"
            "Enter the convective heat-loss rate Q/t in watts. A 2% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 960.0, "correct": True, "feedback": "Correct. Q/t = hAΔT."},
            {"type": "range", "range": [940.8, 979.2], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 940.8], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [979.2, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "Radiation: ε = 0.900, σ = 5.67×10^-8 W/(m^2·K^4), A = 2.00 m^2, T = 300 K.\n\n"
            "Estimate P = εσAT^4 and enter the power in watts. A 3% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 826.0, "correct": True, "feedback": "Correct (within rounding)."},
            {"type": "range", "range": [801.2, 850.8], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 801.2], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [850.8, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A system absorbs Q = 800 J of heat and does W = 250 J of work (physics convention).\n\n"
            "Enter ΔU in joules. A 1% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 550.0, "correct": True, "feedback": "Correct. ΔU = Q − W."},
            {"type": "range", "range": [544.5, 555.5], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 544.5], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [555.5, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

    {
        "question": (
            "A 2.00 kg block slides and friction transfers 600 J of energy into internal energy of the block (no other transfers).\n\n"
            "Enter the change in internal energy ΔU in joules. A 1% tolerance is allowed."
        ),
        "type": "numeric",
        "answers": [
            {"type": "value", "value": 600.0, "correct": True, "feedback": "Correct. The internal energy increases by 600 J."},
            {"type": "range", "range": [594.0, 606.0], "correct": True, "feedback": "Correct within tolerance."},
            {"type": "range", "range": [-999, 594.0], "correct": False, "feedback": "Too small."},
            {"type": "range", "range": [606.0, 9e9], "correct": False, "feedback": "Too large."}
        ]
    },

]

display_quiz(quiz_D7)
# Out:
# <div id="zrObzvADrxWz" data-shufflequestions="False" data-shuffleanswers="True" data-numquestions="1000000"><style>
# :root {
#     --medium-slate-blue: #6f78ffff;
#     --orange-pantone: #f75c03ff;
#     --russian-violet: #392061ff;
#     --maximum-yellow-red: #ffc857ff;
#     --viridian-green: #119da4ff;
#     --incorrect-red: #c80202;
#     --correct-green: #009113;
# }
#
#
# .Quiz {
#      max-width: 600px;
#      margin-top: 15px;
#      margin-left: auto;
#      margin-right: auto;
#      margin-bottom: 15px;
#      padding-bottom: 4px;
#      padding-top: 4px;
#      line-height: 1.1;
#      font-size: 16pt;
# }
#
# .QuizCode {
#     font-size: 14pt;
#     margin-top: 10px;
#     margin-left: 20px;
#     margin-right: 20px;
# }
#
# .QuizCode > pre {
#     padding: 4px;
# }
# .Answer{
#      margin: 10px 0;
#      display: grid;
#      grid-template-columns: auto auto;
#      grid-gap: 10px;
# }
# .Feedback{
#      font-size: 16pt;
#      text-align:center;
#  }
#
# .Input {
# ...
