# %% [markdown]
# # B6.5 Problems
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# ## Problem 6.1: Magnetic Flux Through an Inclined Surface
#
# A **uniform magnetic field** of magnitude $B = 0.25\ \text{T}$ points in the **positive $z$-direction**.
#
# A flat, rectangular surface of area $A = 0.40\ \text{m}^2$ is placed so that its **normal** makes an angle of $60^\circ$ with the magnetic field.
#
# * (a) Find the magnetic flux through the surface.
# * (b) What if the surface were rotated so that it lies parallel to the magnetic field lines?
# * (c) What if the surface were rotated so that it is perpendicular to the magnetic field lines?

# %% [markdown]
# ```{admonition} Problem 6.1: Solution
# :class: tip, dropdown
#
# (a) **Find the magnetic flux through the surface.**
#
# ---
#
# **Solution**
#
# **Step 1: Recall the definition of magnetic flux**
#
# For a uniform field:
#
# $$
# \Phi_B = B\,A\,\cos\theta
# $$
#
# where:
#
# - $B$ = magnitude of magnetic field,
# - $A$ = surface area,
# - $\theta$ = angle between the **field** and the **surface normal**.
#
# ---
#
# **Step 2: Substitute the known values**
#
# Given:
#
# - $B = 0.25\ \text{T}$
# - $A = 0.40\ \text{m}^2$
# - $\theta = 60^\circ$
#
# So:
#
# $$
# \Phi_B = (0.25)(0.40)\cos(60^\circ)
# $$
#
# ---
#
# **Step 3: Evaluate**
#
# - $\cos(60^\circ) = 0.5$
#
# Thus:
#
# $$
# \Phi_B = 0.25 \times 0.40 \times 0.5 = 0.05\ \text{Wb}
# $$
#
# (where $1\ \text{Wb}$ = $1\ \text{T}\cdot\text{m}^2$)
#
# ---
#
# **Answer**
#
# The magnetic flux through the surface is:
#
# $$
# \boxed{\Phi_B = 0.05\ \text{Wb}}
# $$
#
# ---
#
# (b) **What if the surface were rotated so that it lies parallel to the magnetic field lines?**
#
# If the surface is **parallel to the field**, the **normal is perpendicular** to the field, so $\theta = 90^\circ$:
#
# $$
# \Phi_B = B A \cos 90^\circ = 0
# $$
#
# No magnetic flux passes through the surface in this orientation.
#
# ---
#
# (c) **What if the surface were rotated so that it is perpendicular to the magnetic field lines?**
#
# If the surface is **perpendicular** to the field, the **normal is aligned** with the field, so $\theta = 0^\circ$:
#
# $$
# \Phi_B = B A \cos 0^\circ = B A = (0.25)(0.40) = 0.10\ \text{Wb}
# $$
#
# ---
#
# **Key Takeaways**
#
# 1. Magnetic flux is maximal when the surface is **perpendicular** to the field.
# 2. Magnetic flux is zero when the surface is **parallel** to the field.
# 3. Always measure $\theta$ as the angle between the **field** and the **surface normal**.
#
# ```

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.2</h2>
#     </header>
#
# A 50-turn coil has a diameter of $15$ cm. The coil is placed in a spatially uniform magnetic field of magnitude $0.50$ T so that the face of the coil and the magnetic field are perpendicular. Find the magnitude of the emf induced in the coil if the magnetic field is reduced to zero uniformly in
#
# 1. 0.10 s
# 2. 1.0 s
# 3. 60 s.
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import numpy as np

N = 50
D = 0.15
B1 = 0.50
B2 = 0
theta = 0

R = D/2
A = np.pi*R**2

flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)

dt = 0.10
emf = -N*(flux2 - flux1)/dt
print('Induced EMF: '+str(emf)+' V')

dt = 1.0
emf = -N*(flux2 - flux1)/dt
print(' ')
print('Induced EMF: '+str(emf)+' V')

dt = 60
emf = -N*(flux2 - flux1)/dt
print(' ')
print('Induced EMF: '+str(emf)+' V')
# Out:
# Induced EMF: 4.417864669110647 V
#
# Induced EMF: 0.44178646691106466 V
#
# Induced EMF: 0.007363107781851078 V

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.3</h2>
#     </header>
#
# Repeat your calculations of the preceding problem’s time of 0.1 s with the plane of the coil making an angle of
#
# 1. $30.0^\circ$
# 2. $60.0^\circ$
# 3. $90.0^\circ$
#
# with the magnetic field.
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import numpy as np

N = 50
D = 0.15
B1 = 0.50
B2 = 0

R = D/2
A = np.pi*R**2

theta = np.radians(90 - 30.0)
flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)

dt = 0.10
emf = -N*(flux2 - flux1)/dt
print('Induced EMF: '+str(emf)+' V')

theta = np.radians(90 - 60.0)
flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)

dt = 0.10
emf = -N*(flux2 - flux1)/dt
print('Induced EMF: '+str(emf)+' V')


theta = np.radians(90 - 90.0)
flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)

dt = 0.10
emf = -N*(flux2 - flux1)/dt
print('Induced EMF: '+str(emf)+' V')
# Out:
# Induced EMF: 2.208932334555324 V
# Induced EMF: 3.8259830339315535 V
# Induced EMF: 4.417864669110647 V

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.4</h2>
#     </header>
#
# The magnetic field through a circular loop of radius $10.0$ cm varies with time as shown below. The field is perpendicular to the loop. Plot the magnitude of the induced emf in the loop as a function of time.
#
# <img src="P-B6.3.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import numpy as np

N = 1
R = 0.10
theta = 0

A = np.pi*R**2

#first segment
B1 = 0
B2 = 3.0e-3
dt = 2.0e-3
flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)
emf = -N*(flux2 - flux1)/dt
print('Induced EMF: '+str(emf)+' V')

#second segment
B1 = 3.0e-3
B2 = 3.0e-3
dt = 3.0e-3
flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)
emf = -N*(flux2 - flux1)/dt
print(' ')
print('Induced EMF: '+str(emf)+' V')

#thrid segment
B1 = 3.0e-3
B2 = 0
dt = 1.0e-3
flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)
emf = -N*(flux2 - flux1)/dt
print(' ')
print('Induced EMF: '+str(emf)+' V')
# Out:
# Induced EMF: -0.0471238898038469 V
#
# Induced EMF: -0.0 V
#
# Induced EMF: 0.0942477796076938 V

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.5</h2>
#     </header>
#
# The accompanying figure shows a single-turn rectangular coil that has a resistance of $2.0~\Omega$. The magnetic field at all points inside the coil varies according to $B = B_{0}\textrm{e}^{-\alpha t}$, where $B_0 = 0.25$ T and $\alpha = 200.0$ Hz. What is the current induced in the coil at
#
# 1. $t = 0.0010$ s
# 2. $t = 0.0020$ s
# 3. $t = 2.0$ s?
#
# <img src="P-B6.4.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import sympy as sym

R = 2.0
B0 = 0.25
alpha = 200.0
theta = 0.0
N = 1

L = 0.05
W = 0.02

A = L*W

t = sym.Symbol('t')
B = B0*sym.exp(-alpha*t)

flux = B*A*sym.cos(theta)
emf = -N*sym.diff(flux,t)

I = emf/R

t1 = 0.001
I1 = I.evalf(subs={t:t1})
print('Induced current: '+str(I1)+' A')

t1 = 0.002
I1 = I.evalf(subs={t:t1})
print(' ')
print('Induced current: '+str(I1)+' A')

t1 = 2.0
I1 = I.evalf(subs={t:t1})
print(' ')
print('Induced current: '+str(I1)+' A')
# Out:
# Induced current: 0.0204682688269495 A
#
# Induced current: 0.0167580011508910 A
#
# Induced current: 4.78792399178501e-176 A

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.6</h2>
#     </header>
#
# A rectangular wire loop with length a and width b lies in the $xy$-plane, as shown below. Within the loop there is a time-dependent magnetic field given by $\vec{B}(t) = C\left[x\cos(\omega t)~\hat{i} + y\sin(\omega t)~\hat{k}\right]$ T. Determine the emf induced in the loop as a function of time.
#
# <img src="P-B6.5.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import sympy as sym
from sympy.abc import a,b,w,t,x,y,C

B = [C*x*sym.cos(w*t),0,C*y*sym.sin(w*t)]

N = 1

A = [0,0,a*b]

flux = B[0]*A[0] + B[1]*A[1] + B[2]*A[2]
emf = -N*sym.diff(flux,t)
print('Induced emf: '+str(emf)+' V')
# Out:
# Induced emf: -C*a*b*w*y*cos(t*w) V

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.7</h2>
#     </header>
#
# A single-turn circular loop of wire of radius $50.0$ mm lies in a plane perpendicular to a spatially uniform magnetic field. During a $0.10$ s time interval, the magnitude of the field increases uniformly from $200.0$ mT to $300.0$ mT.
#
# 1. Determine the emf induced in the loop.
# 2. If the magnetic field is directed out of the page, what is the direction of the current induced in the loop?
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import numpy as np

N = 1
R = 50.0e-3
theta = 0
dt = 0.10
B1 = 200.0e-3
B2 = 300.0e-3

A = np.pi*R**2

flux1 = B1*A*np.cos(theta)
flux2 = B2*A*np.cos(theta)

emf = -N*(flux2 - flux1)/dt
print('Induced EMF: '+str(emf)+' V')

print(' ')

print('The B-field created by the induced current will act to impose the change.')
print('Since the external field is getting stronger, the induced field will be opposite direction: into the page')
print('An induced field into the page requires a clockwise current.')
# Out:
# Induced EMF: -0.00785398163397448 V
#
# The B-field created by the induced current will act to impose the change.
# Since the external field is getting stronger, the induced field will be opposite direction: into the page
# An induced field into the page requires a clockwise current.

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.8</h2>
#     </header>
#
# When a magnetic field is first turned on, the flux through a 20-turn loop varies with time according to $\phi_m = 5.0t^2 - 2.0t$, where $\phi_m$ is in milliwebers, $t$ is in seconds, and the loop is in the plane of the page with the unit normal pointing outward.
#
# 1. What is the emf induced in the loop as a function of time?
# 2. What is the direction of the induced current at t = 0 s?
# 3. What is the direction of the induced current at t = 0.10 s?
# 4. What is the direction of the induced current at t = 1.0 s?, and (e) 2.0 s?
# 5. What is the direction of the induced current at t = 2.0 s?
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %%
# %reset -f

import sympy as sym
from sympy.abc import t

N = 20
flux = (5.0*t**2 - 2.0*t)/1000  #/1000 since it is given in mW

emf = -N*sym.diff(flux,t)

print('Induced emf: '+str(emf)+' V')

t2 = 0
emf1 = emf.evalf(subs={t:t2})
print('Induced emf: '+str(emf1)+' V')
print('Flux is decreasing, so ')
# Out:
# Induced emf: 0.04 - 0.2*t V
# Induced emf: 0.0400000000000000 V

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.9</h2>
#     </header>
#
# Use Lenz’s law to determine the direction of induced current in each case.
#
# <img src="P-B6.8.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.10</h2>
#     </header>
#
# A current is induced in a circular loop of radius $1.5$ cm between two poles of a horseshoe electromagnet when the current in the electromagnet is varied. The magnetic field in the area of the loop is perpendicular to the area and has a uniform magnitude. If the rate of change of magnetic field is $10.0$ T/s, find the magnitude and direction of the induced current if resistance of the loop is $25~\Omega$.
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %%
# DIY Cell

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.11</h2>
#     </header>
#
# An automobile with a radio antenna $1.0$ m long travels at $100.0$ km/h in a location where the Earth’s horizontal magnetic field is $5.5\times10^{−5}$ T. What is the maximum possible emf induced in the antenna due to this motion?
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.12</h2>
#     </header>
#
# A $25$ cm rod moves at $5.0$ m/s in a plane perpendicular to a magnetic field of strength $0.25$ T. The rod, velocity vector, and magnetic field vector are mutually perpendicular, as indicated in the accompanying figure. Calculate
#
# 1. the magnetic force on an electron in the rod
# 2. the electric field in the rod
# 3. the potential difference between the ends of the rod
# 4. What is the speed of the rod if the potential difference is 1.0 V?
#
# <img src="P-B6.12.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.13</h2>
#     </header>
#
# The rod shown below moves to the right on essentially zero-resistance rails at a speed of $v = 3.0$ m/s.
#
# 1. If $B  = 0.75$ T everywhere in the region, what is the current through the $5.0~\Omega$ resistor?
# 2. Does the current circulate clockwise or counterclockwise?
#
# <img src="P-B6.13.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.14</h2>
#     </header>
#
# Calculate the induced electric field in a $50$ turn coil with a diameter of $15$ cm that is placed in a spatially uniform magnetic field of magnitude $0.50$ T so that the face of the coil and the magnetic field are perpendicular. This magnetic field is reduced to zero in $0.10$ seconds. Assume that the magnetic field is cylindrically symmetric with respect to the central axis of the coil.
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# <h2>Problem B6.15</h2>
#     </header>
#
# Over a region of radius $R$, there is a spatially uniform magnetic field $\vec{B}$. At $t = 0$ s, $B = 1.0$ T, after which it decreases at a constant rate to zero in $30$ s.
#
# 1. What is the electric field in the regions where $r \le R$ and $r \ge R$ during that 30-s interval?
# 2. Assume that $R =10.0$ cm. How much work is done by the electric field on a proton that is carried once clock wise around a circular path of radius $5.0$ cm?
# 3. How much work is done by the electric field on a proton that is carried once counterclockwise around a circular path of any radius $r \ge R$?
# 4. At the instant when $B = 0.50$ T, a proton enters the magnetic field at $A$, moving a velocity $\vec{v}$ $v  = 5.0\times 10^6$ m/s) as shown. What are the electric and magnetic forces on the proton at that instant?
#
# <img src="P-B6.15.png" width="350">
#
# [This problem is a slightly modified version from OpenStax. Access for free here](https://openstax.org/books/university-physics-volume-2/pages/13-problems)

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# ## Problem B6.16: Induced emf in a Rotating, Expanding Loop in a Changing Magnetic Field
#
# A circular metal loop (like a flexible conductive ring in a rotating machine) is placed in a region where the magnetic field is changing with time.
#
# At a particular instant:
#
# - The **magnetic field** is increasing at a rate of $\dfrac{dB}{dt} = 0.30\ \text{T/s}$.
# - The loop’s **radius** is expanding at a rate of $\dfrac{dr}{dt} = 0.002\ \text{m/s}$.
# - The loop is rotating so that the angle between the magnetic field and the loop’s normal is changing at a rate of $\dfrac{d\theta}{dt} = 10\ \text{rad/s}$.
#
# At that instant:
#
# - $B = 0.40\ \text{T}$
# - $r = 0.05\ \text{m}$
# - $\theta = 30^\circ$
#
# **Find the magnitude of the induced emf in the loop at this instant.**

# %% [markdown]
# ```{admonition} Problem B6.16 : Solution
# :class: tip, dropdown
#
# **Solution**
#
# **Step 1: Express the magnetic flux**
#
# For a flat circular loop:
#
# $$
# \Phi_B = B\,A\,\cos\theta \\
# A = \pi r^2
# $$
#
# So:
#
# $$
# \Phi_B = B\,\pi r^2 \cos\theta
# $$
#
# ---
#
# **Step 2: Take the total time derivative**
#
# Using the product rule:
#
# $$
# \frac{d\Phi_B}{dt} =
# A\,\cos\theta\,\frac{dB}{dt}
# \;+\;
# B\,\cos\theta\,\frac{dA}{dt}
# \;-\;
# B\,A\,\sin\theta\,\frac{d\theta}{dt}
# $$
#
# And Faraday’s law:
#
# $$
# \mathcal{E} = -\frac{d\Phi_B}{dt}
# $$
#
# So we need $A$, $dA/dt$, etc.
#
# ---
#
# **Step 3: Compute the area and its rate of change**
#
# - Area:
#
# $$
# A = \pi r^2 = \pi (0.05)^2 \approx 7.85\times10^{-3}\ \text{m}^2
# $$
#
# - Rate of change of area:
#
# Since $A = \pi r^2$,
#
# $$
# \frac{dA}{dt} = 2\pi r\,\frac{dr}{dt} \\
# \frac{dA}{dt} = 2\pi (0.05)(0.002) \approx 6.28\times10^{-4}\ \text{m}^2/\text{s}
# $$
#
# ---
#
# **Step 4: Substitute all known values**
#
# Use:
#
# - $A = 7.85\times10^{-3}\ \text{m}^2$
# - $\theta = 30^\circ$ → $\cos\theta \approx 0.866$, $\sin\theta = 0.5$
# - $B = 0.40\ \text{T}$
# - $dB/dt = 0.30\ \text{T/s}$
# - $dA/dt = 6.28\times10^{-4}\ \text{m}^2/\text{s}$
# - $d\theta/dt = 10\ \text{rad/s}$
#
# Substitute into:
#
# $$
# \mathcal{E} = -\left[A\cos\theta\,\frac{dB}{dt}
# \;+\;
# B\cos\theta\,\frac{dA}{dt}
# \;-\;
# B A\sin\theta\,\frac{d\theta}{dt}\right]
# $$
#
# ---
#
# **Step 5: Calculate each term**
#
# 1. **Due to changing $B$:**
#
# $$
# A\cos\theta\,\frac{dB}{dt} =
# (7.85\times10^{-3})(0.866)(0.30) \\
# \approx 2.04\times10^{-3}\ \text{V}
# $$
#
# 2. **Due to changing $A$:**
#
# $$
# B\cos\theta\,\frac{dA}{dt} =
# (0.40)(0.866)(6.28\times10^{-4}) \\
# \approx 2.18\times10^{-4}\ \text{V}
# $$
#
# 3. **Due to changing $\theta$:**
#
# $$
# -\,B A \sin\theta\,\frac{d\theta}{dt} =
# - (0.40)(7.85\times10^{-3})(0.5)(10) \\
# = -1.57\times10^{-2}\ \text{V}
# $$
#
# ---
#
# **Step 6: Sum them up**
#
# Inside the brackets:
#
# $$
# \big[\,\dots\,\big] =
# (2.04\times10^{-3})
# + (2.18\times10^{-4})
# - (-1.57\times10^{-2}) \\
# = 2.04\times10^{-3} + 2.18\times10^{-4} + 1.57\times10^{-2} \\
# \approx 1.79\times10^{-2}\ \text{V}
# $$
#
# Then:
#
# $$
# \mathcal{E} = - (1.79\times10^{-2})\ \text{V}
# $$
#
# The negative sign tells us the **direction** opposes the change (Lenz’s law).
#
# ---
#
# **Step 7: Final Answer**
#
# The **magnitude** of the induced emf:
#
# $$
# \boxed{|\mathcal{E}| \approx 1.8\times10^{-2}\ \text{V}\ \ (18\ \text{mV})}
# $$
#
# ---
#
# **Discussion**
#
# - The dominant contribution is from the **rotation** term ($B A \sin\theta\,d\theta/dt$), which is why generators rely on rotating coils.
# - The changing $B$ and expanding area contribute less here but can dominate in other setups.
#
# ```

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
