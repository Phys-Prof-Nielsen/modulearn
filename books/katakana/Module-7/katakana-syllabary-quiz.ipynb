# %% [markdown]
# # Katakana Syllabary Quizzes
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# ## Katakana - Romaji MC Quiz
#
# [Access Quiz](quiz-katakana-romaji-MC.html)
#
#
# ## Katakana - Romaji Input Quiz
#
# [Access Quiz](quiz-katakana-romaji-input.html)

# %% [markdown]
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
