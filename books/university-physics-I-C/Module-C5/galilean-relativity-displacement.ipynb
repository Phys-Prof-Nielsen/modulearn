# %% [markdown]
# # C5.3 Galilean Relativity: Displacement Measurement
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# ## C5.3.1 Introduction
#
# At first glance, displacement may sound similar to measuring length — but it is fundamentally different.
#
# **Length** is a measurement that can be taken at a *single instant in time*.
# **Displacement**, by definition, describes how far (and in what direction) an object moves **between two events**.
#
# Displacement therefore requires:
#
# - An initial position
# - A final position
# - The time interval between those positions
#
# It is inherently tied to motion and time.
#
# <div style="background-color:#e6f0ff; border-left:6px solid #003366; padding:14px; border-radius:4px;">
# <h3 style="margin-top:0; color:#000000;">Important Point</h3>
#
# An observer in $S'$ measures two different positions $x'_1$ and $x'_2$ at two different times $t'_1$ and $t'_2$.
#
# An observer in $S$ measures corresponding positions $x_1$ and $x_2$ at two different times $t_1$ and $t_2$.
#
# Notice that we now have **two distinct events** measured by two observers:
#
# - Event 1: $(x_1, t_1)$, $(x'_1, t'_1)$
# - Event 2: $(x_2, t_2)$, $(x'_2, t'_2)$
#
# Displacement is defined between these two events in their respective frames.
#
# </div>
#
# This is the crucial distinction:
#
# - A **length measurement** compares two spatial points usually at the *same time*.
# - A **displacement measurement** compares the position of the *same object* at two different times.
#
# Because displacement involves two events, it is inherently more subtle than a simple length measurement — especially when comparing observations between different reference frames.
#
# Take a moment to discuss this distinction with a classmate, neighbor, family member, or friend. Make sure you can clearly explain the difference between:
#
# - Measuring the length of an object
# - Measuring the displacement of a moving object
#
# If you can explain the difference clearly to someone else, you understand it.
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# ## C5.3.2 Derivation
#
# We will now proceed to measure these two events in similar fashion as the previous case (no relative motion in $y$ and $z$), no need for time synchronization, and a relative constant velocity $\vec{u}$ in $x$-direction of $S'$ relative to $S$. The events are characterized by
#
# * Event 1: ($x_1$,$t_1$) and ($x'_1$,$t'_1$)
# * Event 2: ($x_2$,$t_2$) and ($x'_2$,$t'_2$)
#
# <img src="C5-fig9.png" width="600">
#
# Per definition of displacement, we have the following:
#
# * Observer $S'$: $\Delta \vec{x}' = \vec{x}'_{2}(t'_{2}) - \vec{x}'_{1}(t'_{1})$
# * Observer $S$: $\Delta \vec{x} = \vec{x}_{2}(t_2) - \vec{x}_{1}(t_1)$
#
# From Newtonian physics point of view, the elapsed time interval $\Delta t$ must be the same for both observers: $\Delta t = t_2 - t_1 = t'_2 - t'_1$. We can then, by virtue of geometric vector algebra write the following relationship:
#
# $$ \vec{x}_2 - \vec{x}_1 = \vec{x}'_2 + (\vec{u}\Delta t - \vec{x}'_1) $$
#
# or
#
# $$ \Delta\vec{x} = \Delta\vec{x}' + \vec{u}\Delta t $$
#
# We can extrapolate this into the other directions to come up with the general rule(s) for displacement transformation:
#
# <div style="background-color:#e6f0ff; border-left:6px solid #003366; padding:14px; border-radius:4px;">
# <h3 style="margin-top:0; color:#000000;">Displacement in Galilean Relativity</h3>
#
# $$ \Delta\vec{r} = \Delta\vec{r}' + \vec{u}\Delta t \tag{1}$$
#
# $$ \Delta\vec{r}' = \Delta\vec{r} + \vec{u}'\Delta t' \tag{2}$$
# </div>
#
# With the transformation of displacement, it becomes straightforward to show the **Galilean velocity transformation**.
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
