# %% [markdown]
# # B1.11 Module B1 Assessment
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">

# %% [markdown]
# ## Problem 1: Computing a Derivative Using Symbolic Python
# Given the function for position as a function of time:
#
# $$
# x(t) = 5t^3 - 2t^2 + 4t - 7
# $$
#
# 1. Compute the velocity $ v_x(t) $ as the derivative of $ x(t) $ using SymPy in Python.
# 2. Verify your result in (1) through differentiation by hand.
# 3. Evaluate the velocity at $ t = 2 $ seconds.
# 4. Interpret the result in the context of motion.
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
#
# ## Problem 2: Instantaneous Acceleration
# The velocity of a particle moving in one dimension is given by:
#
# $$
# v_x(t) = 3t^2 - 6t + 2
# $$
#
# 1. Find the acceleration $ a_x(t) $ by differentiating $ v_x(t) $.
# 2. Determine the instantaneous acceleration at $ t = 4 $ s.
# 3. Explain what the sign of $ x(t) $ at $ t = 4 $ s indicates about the motion of the particle.
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
#
# ## Problem 3: Evaluating an Indefinite Integral
# Consider the force acting on an object given by:
#
# $$
# f_x(x) = 6x^2 - 4x + 3
# $$
#
# 1. Compute the work done by this force over a displacement $ \Delta x $ by finding the definite integral:
#
# $$
#    w(x) = \int_{x_1}^{x_2} f_x(x) \, dx
# $$
#
# 2. What is the physical meaning of the constant of integration in this context?
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
#
# ## Problem 4: Definite Integral and Work Calculation
# A force function is given by:
#
# $$
# f(x) = 10x
# $$
#
# Find the total work done by this force in moving an object from $ x = 2 $ m to $ x = 5 $ m using integration.
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
#
# ## Problem 5: Using Python for Symbolic Integration
# Using SymPy in Python, evaluate the following integral:
#
# $$
# I = \int (4t^3 - 2t + 7) dt
# $$
#
# 1. Compute the integral symbolically.
# 2. Verify the result by differentiating it.
# 3. Explain how integration relates to differentiation in this example.
#
# <hr style="height:2px;border-width:0;color:gray;background-color:gray">
